# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support

import os
import pickle

import json

# %%
from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %%
def get_feature_list(model):
    
    '''This function looks for the dictionary associated with a model 
    to get the features we used during the fit automatically as a list
    '''
       
    models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Not Normalized Togehter\MODELS"
    dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Not Normalized Togehter\DICTS"

    list_models = os.listdir(models_path)[:-3]
    list_dicts = os.listdir(dict_path)
    
    # print(len(list_models), list_models)
    # print(len(list_dicts),list_dicts)
    
       
    for i in range(len(list_dicts)):

        model_name = str(model).split(".")[0]
        name_dict = str(list_dicts[i]).split(".")[0]
        
        if model_name == name_dict:
            
            dict_path = str(dict_path)+ r"\{}".format(str(list_dicts[i]))
            
            with open(dict_path) as f:
                data = json.load(f)
            
            model_name = data["name"]
            features = data["features"]
            model_type = data["model"]
        # print(features)
        
        model_path = str(models_path) + r"\{}".format(model)
        
    return features, model_name, model_type, model_path



def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def data_cleaning(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y_test = data["Polarity"] #outcomes 0 or 1


  # print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  # for feature in feature_cols:
  #   print(feature)

  return X, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores


def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  plt.title("{} Confusion Matrix: ".format(model_name), y = 1.1)



  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(model, model_type, model_name, X, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''
    
    
    
  model_dict = {}

  model_dict["name"] = model_name

  model_dict["features"] = features

  model_dict["model"] = model_type

  print("\n",model_name, "\n", "\n")

  y_pred = model.predict(X)

  accuracy = accuracy_score(y_test, y_pred)

  model_dict["accuracy"] = accuracy

  print("OVERALL ACCURACY", model_dict["name"], ":", round(accuracy*100, 2),"%""\n")

  scores = class_report(y_test, y_pred)

  P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
  precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]

  P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
  precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]

  model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
  model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

  confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")

  model_dict["confussion_matrix"] = confussion_matrix
  
  model_dict["data_test_source"] = "second dataset"
  
  model_dict["training_normalized_together"] = "no"

  model_dict["testing_normalized_together"] = "yes"

  with open(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Testing\Testing normalized together\With not normalized together training\{}_TEST.json".format(model_dict["name"]), "w") as f:
    json.dump(model_dict, f, cls=NumpyArrayEncoder)
    
    
  return model_dict

# %%
def magic_eva(data, model):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''
  
  features, model_name, model_type, model_path = get_feature_list(model)

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y_test, features = data_cleaning(data, features) # data split for all the models with the desired features
  
  model = pickle.load(open (model_path, "rb"))

  model_dict = compare_models_train_test_split(model, model_type, model_name, X, y_test, features) # for each model it will compute

  return model_dict

# %%
data = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\test_data_normalized_together.csv")

# %%
models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Not Normalized Togehter\MODELS"
dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Not Normalized Togehter\DICTS"

list_models = os.listdir(models_path)
list_dicts = os.listdir(dict_path)

list_dicts_performance = []

for model in list_models:
    dict_model = magic_eva(data, model)
    
    list_dicts_performance.append(dict_model)
    # print(dict_model)
# Out:
#  All_features__KNeighborsClassifier
#
#
# OVERALL ACCURACY All_features__KNeighborsClassifier : 48.72 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.48      0.08      0.13      3079
#         Real       0.49      0.91      0.64      2968
#
#     accuracy                           0.49      6047
#    macro avg       0.48      0.49      0.38      6047
# weighted avg       0.48      0.49      0.38      6047
#
#
#  All_features__LogisticRegression
#
#
# OVERALL ACCURACY All_features__LogisticRegression : 50.11 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.05      0.09      3079
#         Real       0.50      0.97      0.66      2968
#
#     accuracy                           0.50      6047
#    macro avg       0.56      0.51      0.37      6047
# weighted avg       0.57      0.50      0.37      6047
#
#
#  All_features__RandomForestClassifier
#
#
# OVERALL ACCURACY All_features__RandomForestClassifier : 49.48 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      3079
#         Real       0.49      1.00      0.66      2968
#
#     accuracy                           0.49      6047
#    macro avg       0.75      0.50      0.34      6047
# weighted avg       0.75      0.49      0.33      6047
#
#
#  All_features__SVC
#
#
# OVERALL ACCURACY All_features__SVC : 49.53 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.01      0.03      3079
#         Real       0.49      1.00      0.66      2968
#
#     accuracy                           0.50      6047
#    macro avg       0.62      0.50      0.34      6047
# weighted avg       0.62      0.50      0.34      6047
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 52.97 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 52.97 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 53.08 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.88      0.01      0.02      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.71      0.50      0.35      5526
# weighted avg       0.70      0.53      0.37      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 52.97 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 47.54 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.45      0.54      0.49      2613
#         Real       0.50      0.42      0.46      2913
#
#     accuracy                           0.48      5526
#    macro avg       0.48      0.48      0.47      5526
# weighted avg       0.48      0.48      0.47      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 54.38 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.05      0.10      2613
#         Real       0.54      0.98      0.69      2913
#
#     accuracy                           0.54      5526
#    macro avg       0.64      0.52      0.40      5526
# weighted avg       0.64      0.54      0.41      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 46.07 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.46      0.88      0.61      2613
#         Real       0.44      0.08      0.14      2913
#
#     accuracy                           0.46      5526
#    macro avg       0.45      0.48      0.37      5526
# weighted avg       0.45      0.46      0.36      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__SVC : 54.51 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.74      0.06      0.11      2613
#         Real       0.54      0.98      0.69      2913
#
#     accuracy                           0.55      5526
#    macro avg       0.64      0.52      0.40      5526
# weighted avg       0.63      0.55      0.42      5526
#
#
#  DESWLltd__DESPLd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__KNeighborsClassifier : 52.99 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__LogisticRegression : 52.93 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.00      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__RandomForestClassifier : 52.99 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.86      0.01      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.69      0.50      0.35      5526
# weighted avg       0.68      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__SVC
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__SVC : 52.93 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.00      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__KNeighborsClassifier : 50.49 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      3159
#         Real       0.50      1.00      0.67      3171
#
#     accuracy                           0.50      6330
#    macro avg       0.75      0.50      0.34      6330
# weighted avg       0.75      0.50      0.34      6330
#
#
#  DESWLltd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__LogisticRegression : 50.39 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      3159
#         Real       0.50      1.00      0.67      3171
#
#     accuracy                           0.50      6330
#    macro avg       0.75      0.50      0.34      6330
# weighted avg       0.75      0.50      0.34      6330
#
#
#  DESWLltd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__RandomForestClassifier : 50.85 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.91      0.02      0.03      3159
#         Real       0.50      1.00      0.67      3171
#
#     accuracy                           0.51      6330
#    macro avg       0.71      0.51      0.35      6330
# weighted avg       0.71      0.51      0.35      6330
#
#
#  DESWLltd__SVC
#
#
# OVERALL ACCURACY DESWLltd__SVC : 50.41 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      3159
#         Real       0.50      1.00      0.67      3171
#
#     accuracy                           0.50      6330
#    macro avg       0.75      0.50      0.34      6330
# weighted avg       0.75      0.50      0.34      6330
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 50.78 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      3134
#         Real       0.51      1.00      0.67      3170
#
#     accuracy                           0.51      6304
#    macro avg       0.75      0.50      0.35      6304
# weighted avg       0.75      0.51      0.35      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 50.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      3134
#         Real       0.50      1.00      0.67      3170
#
#     accuracy                           0.51      6304
#    macro avg       0.75      0.50      0.34      6304
# weighted avg       0.75      0.51      0.34      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 51.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.76      0.02      0.04      3134
#         Real       0.51      0.99      0.67      3170
#
#     accuracy                           0.51      6304
#    macro avg       0.63      0.51      0.36      6304
# weighted avg       0.63      0.51      0.36      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
# C:\Users\alber\AppData\Local\Temp\ipykernel_20056\4284352635.py:97: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 50.6 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.01      3134
#         Real       0.50      1.00      0.67      3170
#
#     accuracy                           0.51      6304
#    macro avg       0.75      0.50      0.34      6304
# weighted avg       0.75      0.51      0.34      6304

# %%
print(len(list_dicts_performance))
print(list_dicts_performance)
# Out:
# 24
# [{'name': 'All_features__KNeighborsClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'KNeighborsClassifier', 'accuracy': 0.487183727468166, 'precision_true': array([0.48804602]), 'recall_true': array([0.91475741]), 'f1_score_true': array([0.63650217]), 'precision_false': array([0.47727273]), 'recall_false': array([0.07502436]), 'f1_score_false': array([0.12966601]), 'confussion_matrix': array([[ 231,  253],
#        [2848, 2715]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'All_features__LogisticRegression', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'LogisticRegression', 'accuracy': 0.5010749131800893, 'precision_true': array([0.49578531]), 'recall_true': array([0.97102426]), 'f1_score_true': array([0.65641726]), 'precision_false': array([0.63247863]), 'recall_false': array([0.04806755]), 'f1_score_false': array([0.089345]), 'confussion_matrix': array([[ 148,   86],
#        [2931, 2882]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'All_features__RandomForestClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'RandomForestClassifier', 'accuracy': 0.4947908053580288, 'precision_true': array([0.49277769]), 'recall_true': array([1.]), 'f1_score_true': array([0.66021577]), 'precision_false': array([1.]), 'recall_false': array([0.00779474]), 'f1_score_false': array([0.0154689]), 'confussion_matrix': array([[  24,    0],
#        [3055, 2968]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'All_features__SVC', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'SVC', 'accuracy': 0.49528691913345463, 'precision_true': array([0.49299065]), 'recall_true': array([0.99528302]), 'f1_score_true': array([0.659375]), 'precision_false': array([0.74545455]), 'recall_false': array([0.01331601]), 'f1_score_false': array([0.02616465]), 'confussion_matrix': array([[  41,   14],
#        [3038, 2954]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5296778863554108, 'precision_true': array([0.52848331]), 'recall_true': array([1.]), 'f1_score_true': array([0.69151335]), 'precision_false': array([1.]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.01065855]), 'confussion_matrix': array([[  14,    0],
#        [2599, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5296778863554108, 'precision_true': array([0.52848331]), 'recall_true': array([1.]), 'f1_score_true': array([0.69151335]), 'precision_false': array([1.]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.01065855]), 'confussion_matrix': array([[  14,    0],
#        [2599, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.5307636626854868, 'precision_true': array([0.52909091]), 'recall_true': array([0.99897013]), 'f1_score_true': array([0.69178652]), 'precision_false': array([0.88461538]), 'recall_false': array([0.00880214]), 'f1_score_false': array([0.01743085]), 'confussion_matrix': array([[  23,    3],
#        [2590, 2910]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5296778863554108, 'precision_true': array([0.52848331]), 'recall_true': array([1.]), 'f1_score_true': array([0.69151335]), 'precision_false': array([1.]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.01065855]), 'confussion_matrix': array([[  14,    0],
#        [2599, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.47538906985161056, 'precision_true': array([0.50289735]), 'recall_true': array([0.41709578]), 'f1_score_true': array([0.4559955]), 'precision_false': array([0.45401929]), 'recall_false': array([0.54037505]), 'f1_score_false': array([0.49344749]), 'confussion_matrix': array([[1412, 1698],
#        [1201, 1215]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5437929786463989, 'precision_true': array([0.53667665]), 'recall_true': array([0.98455201]), 'f1_score_true': array([0.6946833]), 'precision_false': array([0.75274725]), 'recall_false': array([0.05243016]), 'f1_score_false': array([0.0980322]), 'confussion_matrix': array([[ 137,   45],
#        [2476, 2868]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.4607310893955845, 'precision_true': array([0.43807763]), 'recall_true': array([0.08135942]), 'f1_score_true': array([0.13723219]), 'precision_false': array([0.46318957]), 'recall_false': array([0.88365863]), 'f1_score_false': array([0.60779152]), 'confussion_matrix': array([[2309, 2676],
#        [ 304,  237]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5450597176981542, 'precision_true': array([0.53749295]), 'recall_true': array([0.9818057]), 'f1_score_true': array([0.69468059]), 'precision_false': array([0.74146341]), 'recall_false': array([0.05817069]), 'f1_score_false': array([0.10787793]), 'confussion_matrix': array([[ 152,   53],
#        [2461, 2860]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__KNeighborsClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5298588490770901, 'precision_true': array([0.52857921]), 'recall_true': array([1.]), 'f1_score_true': array([0.69159544]), 'precision_false': array([1.]), 'recall_false': array([0.00574053]), 'f1_score_false': array([0.01141553]), 'confussion_matrix': array([[  15,    0],
#        [2598, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__LogisticRegression', 'features': ['DESWLltd', 'DESPLd'], 'model': 'LogisticRegression', 'accuracy': 0.5293159609120521, 'precision_true': array([0.52829162]), 'recall_true': array([1.]), 'f1_score_true': array([0.69134923]), 'precision_false': array([1.]), 'recall_false': array([0.00459242]), 'f1_score_false': array([0.00914286]), 'confussion_matrix': array([[  12,    0],
#        [2601, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__RandomForestClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'RandomForestClassifier', 'accuracy': 0.5298588490770901, 'precision_true': array([0.52861035]), 'recall_true': array([0.99897013]), 'f1_score_true': array([0.69137562]), 'precision_false': array([0.85714286]), 'recall_false': array([0.00688863]), 'f1_score_false': array([0.01366743]), 'confussion_matrix': array([[  18,    3],
#        [2595, 2910]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__SVC', 'features': ['DESWLltd', 'DESPLd'], 'model': 'SVC', 'accuracy': 0.5293159609120521, 'precision_true': array([0.52829162]), 'recall_true': array([1.]), 'f1_score_true': array([0.69134923]), 'precision_false': array([1.]), 'recall_false': array([0.00459242]), 'f1_score_false': array([0.00914286]), 'confussion_matrix': array([[  12,    0],
#        [2601, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__KNeighborsClassifier', 'features': ['DESWLltd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5048973143759874, 'precision_true': array([0.50293418]), 'recall_true': array([1.]), 'f1_score_true': array([0.66926973]), 'precision_false': array([1.]), 'recall_false': array([0.0079139]), 'f1_score_false': array([0.01570352]), 'confussion_matrix': array([[  25,    0],
#        [3134, 3171]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__LogisticRegression', 'features': ['DESWLltd'], 'model': 'LogisticRegression', 'accuracy': 0.5039494470774092, 'precision_true': array([0.50245603]), 'recall_true': array([1.]), 'f1_score_true': array([0.66884623]), 'precision_false': array([1.]), 'recall_false': array([0.00601456]), 'f1_score_false': array([0.01195721]), 'confussion_matrix': array([[  19,    0],
#        [3140, 3171]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__RandomForestClassifier', 'features': ['DESWLltd'], 'model': 'RandomForestClassifier', 'accuracy': 0.5085308056872038, 'precision_true': array([0.50478316]), 'recall_true': array([0.99842321]), 'f1_score_true': array([0.67054961]), 'precision_false': array([0.9137931]), 'recall_false': array([0.01677746]), 'f1_score_false': array([0.03294995]), 'confussion_matrix': array([[  53,    5],
#        [3106, 3166]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__SVC', 'features': ['DESWLltd'], 'model': 'SVC', 'accuracy': 0.5041074249605055, 'precision_true': array([0.50253566]), 'recall_true': array([1.]), 'f1_score_true': array([0.66891678]), 'precision_false': array([1.]), 'recall_false': array([0.00633112]), 'f1_score_false': array([0.01258257]), 'confussion_matrix': array([[  20,    0],
#        [3139, 3171]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5077728426395939, 'precision_true': array([0.50534035]), 'recall_true': array([1.]), 'f1_score_true': array([0.6713968]), 'precision_false': array([1.]), 'recall_false': array([0.00989151]), 'f1_score_false': array([0.01958926]), 'confussion_matrix': array([[  31,    0],
#        [3103, 3170]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5066624365482234, 'precision_true': array([0.50477707]), 'recall_true': array([1.]), 'f1_score_true': array([0.67089947]), 'precision_false': array([1.]), 'recall_false': array([0.00765795]), 'f1_score_false': array([0.01519949]), 'confussion_matrix': array([[  24,    0],
#        [3110, 3170]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.509993654822335, 'precision_true': array([0.5065144]), 'recall_true': array([0.99337539]), 'f1_score_true': array([0.67092788]), 'precision_false': array([0.75862069]), 'recall_false': array([0.02105935]), 'f1_score_false': array([0.04098106]), 'confussion_matrix': array([[  66,   21],
#        [3068, 3149]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5060279187817259, 'precision_true': array([0.50445576]), 'recall_true': array([1.]), 'f1_score_true': array([0.67061561]), 'precision_false': array([1.]), 'recall_false': array([0.00638162]), 'f1_score_false': array([0.01268231]), 'confussion_matrix': array([[  20,    0],
#        [3114, 3170]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'no', 'testing_normalized_together': 'yes'}]

# %% [markdown]
# do a mirror pair of models trained with this data and tested in the second dataset/fine tune

# %% [markdown]
# '''
#
# small crossvalidation to make sure model is stableand std bt the scores , lucky distr.
#
# data augmentation - + at the end with the generation model, feed the model with new elements
#
# method to input some text and see the prediction irt,
# automatically add fake news text to the data
#
#
# this is quant but we need qualitative
#
# SMOTE libary for DAug
#
# name of the file and template of the acl file - subsections things
#
# qualitative vs quantitative studies
#
# '''

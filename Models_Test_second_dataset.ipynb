# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support


import pickle

import json

# %%
from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %%
def get_feature_list(model):
    
    '''This function looks for the dictionary associated with a model 
    to get the features we used during the fit automatically as a list
    '''
       
    models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\Models"
    dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\Models\Info Dictionaries"

    list_models = os.listdir(models_path)[:-3]
    list_dicts = os.listdir(dict_path)
    
    # print(len(list_models), list_models)
    # print(len(list_dicts),list_dicts)
    
       
    for i in range(len(list_dicts)):

        model_name = str(model).split(".")[0]
        name_dict = str(list_dicts[i]).split(".")[0]
        
        if model_name == name_dict:
            
            dict_path = str(dict_path)+ r"\{}".format(str(list_dicts[i]))
            
            with open(dict_path) as f:
                data = json.load(f)
            
            model_name = data["name"]
            features = data["features"]
            model_type = data["model"]
        # print(features)
        
        model_path = str(models_path) + r"\{}".format(model)
        
    return features, model_name, model_type, model_path



def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def data_cleaning(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y_test = data["Polarity"] #outcomes 0 or 1


  # print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  # for feature in feature_cols:
  #   print(feature)

  return X, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores


def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  plt.title("{} Confusion Matrix: ".format(model_name), y = 1.1)



  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(model, model_type, model_name, X, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''
    
    
    
  model_dict = {}

  model_dict["name"] = model_name

  model_dict["features"] = features

  model_dict["model"] = model_type

  print("\n",model_name, "\n", "\n")

  y_pred = model.predict(X)

  accuracy = accuracy_score(y_test, y_pred)

  model_dict["accuracy"] = accuracy

  print("OVERALL ACCURACY", model_dict["name"], ":", round(accuracy*100, 2),"%""\n")

  scores = class_report(y_test, y_pred)

  P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
  precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]

  P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
  precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]

  model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
  model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

  confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")

  model_dict["confussion_matrix"] = confussion_matrix

  with open(r"C:\Users\alber\Desktop\Make Believe Diciembre\Models\Info Dictionaries\{}_TEST.json".format(model_dict["name"]), "w") as f:
    json.dump(model_dict, f, cls=NumpyArrayEncoder)
    
    
  return model_dict

# %%
def magic_eva(data, model):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''
  
  features, model_name, model_type, model_path = get_feature_list(model)

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y_test, features = data_cleaning(data, features) # data split for all the models with the desired features
  
  model = pickle.load(open (model_path, "rb"))

  model_dict = compare_models_train_test_split(model, model_type, model_name, X, y_test, features) # for each model it will compute

  return model_dict

# %%
data = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\test_data")

# %%
list_models
# Out:
# ['All_features__KNeighborsClassifier.sav',
#  'All_features__LogisticRegression.sav',
#  'All_features__RandomForestClassifier.sav',
#  'All_features__SVC.sav',
#  'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier.sav',
#  'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression.sav',
#  'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier.sav',
#  'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC.sav',
#  'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier.sav',
#  'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression.sav',
#  'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier.sav',
#  'DESPLd__WORD_PROPERTY_WRDHYPn__SVC.sav',
#  'DESWLltd__DESPLd__KNeighborsClassifier.sav',
#  'DESWLltd__DESPLd__LogisticRegression.sav',
#  'DESWLltd__DESPLd__RandomForestClassifier.sav',
#  'DESWLltd__DESPLd__SVC.sav',
#  'DESWLltd__KNeighborsClassifier.sav',
#  'DESWLltd__LogisticRegression.sav',
#  'DESWLltd__RandomForestClassifier.sav',
#  'DESWLltd__SVC.sav',
#  'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier.sav',
#  'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression.sav',
#  'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier.sav',
#  'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC.sav',
#  'Info Dictionaries']

# %%
models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\Models"
dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\Models\Info Dictionaries"

list_models = os.listdir(models_path)[:-3]
list_dicts = os.listdir(dict_path)

list_dicts_performance = []

for model in list_models:
    dict_model = magic_eva(data, model)
    
    list_dicts_performance.append(dict_model)
    # print(dict_model)
# Out:
#  All_features__KNeighborsClassifier
#
#
# OVERALL ACCURACY All_features__KNeighborsClassifier : 50.09 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.08      0.13      3079
#         Real       0.50      0.94      0.65      2968
#
#     accuracy                           0.50      6047
#    macro avg       0.54      0.51      0.39      6047
# weighted avg       0.54      0.50      0.39      6047
#
#
#  All_features__LogisticRegression
#
#
# OVERALL ACCURACY All_features__LogisticRegression : 64.88 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.93      0.34      0.49      3079
#         Real       0.59      0.97      0.73      2968
#
#     accuracy                           0.65      6047
#    macro avg       0.76      0.65      0.61      6047
# weighted avg       0.76      0.65      0.61      6047
#
#
#  All_features__RandomForestClassifier
#
#
# OVERALL ACCURACY All_features__RandomForestClassifier : 3.03 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3079
#         Real       0.05      0.05      0.05      2968
#
#     accuracy                           0.03      6047
#    macro avg       0.03      0.03      0.03      6047
# weighted avg       0.03      0.03      0.03      6047
#
#
#  All_features__SVC
#
#
# OVERALL ACCURACY All_features__SVC : 53.08 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.94      0.08      0.15      3079
#         Real       0.51      0.99      0.68      2968
#
#     accuracy                           0.53      6047
#    macro avg       0.73      0.54      0.41      6047
# weighted avg       0.73      0.53      0.41      6047
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 16.81 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.26      0.31      0.28      2913
#
#     accuracy                           0.17      5526
#    macro avg       0.13      0.16      0.15      5526
# weighted avg       0.14      0.17      0.15      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 23.31 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.33      0.44      0.38      2913
#
#     accuracy                           0.23      5526
#    macro avg       0.17      0.22      0.19      5526
# weighted avg       0.18      0.23      0.20      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 4.87 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.09      0.08      0.09      2913
#
#     accuracy                           0.05      5526
#    macro avg       0.05      0.05      0.05      5526
# weighted avg       0.05      0.05      0.05      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 16.72 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.26      0.31      0.28      2913
#
#     accuracy                           0.17      5526
#    macro avg       0.13      0.16      0.14      5526
# weighted avg       0.14      0.17      0.15      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 69.54 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.54      0.63      2613
#         Real       0.67      0.83      0.74      2913
#
#     accuracy                           0.70      5526
#    macro avg       0.71      0.69      0.68      5526
# weighted avg       0.71      0.70      0.69      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 51.19 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.38      0.05      0.09      2613
#         Real       0.52      0.92      0.67      2913
#
#     accuracy                           0.51      5526
#    macro avg       0.45      0.49      0.38      5526
# weighted avg       0.46      0.51      0.39      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 88.45 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.87      0.89      0.88      2613
#         Real       0.90      0.88      0.89      2913
#
#     accuracy                           0.88      5526
#    macro avg       0.88      0.88      0.88      5526
# weighted avg       0.88      0.88      0.88      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__SVC : 51.19 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.39      0.06      0.10      2613
#         Real       0.52      0.92      0.67      2913
#
#     accuracy                           0.51      5526
#    macro avg       0.46      0.49      0.38      5526
# weighted avg       0.46      0.51      0.40      5526
#
#
#  DESWLltd__DESPLd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__KNeighborsClassifier : 8.16 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.14      0.15      0.15      2913
#
#     accuracy                           0.08      5526
#    macro avg       0.07      0.08      0.08      5526
# weighted avg       0.08      0.08      0.08      5526
#
#
#  DESWLltd__DESPLd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__LogisticRegression : 31.23 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.00      0.01      2613
#         Real       0.40      0.59      0.47      2913
#
#     accuracy                           0.31      5526
#    macro avg       0.20      0.30      0.24      5526
# weighted avg       0.21      0.31      0.25      5526
#
#
#  DESWLltd__DESPLd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__RandomForestClassifier : 5.61 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      2613
#         Real       0.10      0.10      0.10      2913
#
#     accuracy                           0.06      5526
#    macro avg       0.05      0.05      0.05      5526
# weighted avg       0.06      0.06      0.06      5526
#
#
#  DESWLltd__DESPLd__SVC
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__SVC : 20.77 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.00      0.01      2613
#         Real       0.30      0.39      0.34      2913
#
#     accuracy                           0.21      5526
#    macro avg       0.16      0.20      0.17      5526
# weighted avg       0.16      0.21      0.18      5526
#
#
#  DESWLltd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__KNeighborsClassifier : 1.44 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3159
#         Real       0.02      0.02      0.02      3171
#
#     accuracy                           0.01      6330
#    macro avg       0.01      0.01      0.01      6330
# weighted avg       0.01      0.01      0.01      6330
#
#
#  DESWLltd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__LogisticRegression : 7.28 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3159
#         Real       0.12      0.14      0.13      3171
#
#     accuracy                           0.07      6330
#    macro avg       0.07      0.07      0.07      6330
# weighted avg       0.07      0.07      0.07      6330
#
#
#  DESWLltd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__RandomForestClassifier : 2.26 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.02      0.02      0.02      3159
#         Real       0.03      0.03      0.03      3171
#
#     accuracy                           0.02      6330
#    macro avg       0.02      0.02      0.02      6330
# weighted avg       0.02      0.02      0.02      6330
#
#
#  DESWLltd__SVC
#
#
# OVERALL ACCURACY DESWLltd__SVC : 6.79 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3159
#         Real       0.12      0.13      0.12      3171
#
#     accuracy                           0.07      6330
#    macro avg       0.06      0.07      0.06      6330
# weighted avg       0.06      0.07      0.06      6330
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 2.49 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3134
#         Real       0.04      0.04      0.04      3170
#
#     accuracy                           0.02      6304
#    macro avg       0.02      0.02      0.02      6304
# weighted avg       0.02      0.02      0.02      6304
# C:\Users\alber\AppData\Local\Temp\ipykernel_23312\218045958.py:97: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
#  DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 3.82 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3134
#         Real       0.07      0.07      0.07      3170
#
#     accuracy                           0.04      6304
#    macro avg       0.04      0.04      0.04      6304
# weighted avg       0.04      0.04      0.04      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 1.7 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3134
#         Real       0.02      0.02      0.02      3170
#
#     accuracy                           0.02      6304
#    macro avg       0.02      0.02      0.02      6304
# weighted avg       0.02      0.02      0.02      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 4.11 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.01      0.01      0.01      3134
#         Real       0.07      0.08      0.07      3170
#
#     accuracy                           0.04      6304
#    macro avg       0.04      0.04      0.04      6304
# weighted avg       0.04      0.04      0.04      6304

# %%
print(len(list_dicts_performance))
print(list_dicts_performance)
# Out:
# 24
# [{'name': 'All_features__KNeighborsClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5009095419216141, 'precision_true': array([0.49556895]), 'recall_true': array([0.94204852]), 'f1_score_true': array([0.64947735]), 'precision_false': array([0.57530864]), 'recall_false': array([0.07567392]), 'f1_score_false': array([0.13375431]), 'confussion_matrix': array([[ 233,  172],
#        [2846, 2796]], dtype=int64)}, {'name': 'All_features__LogisticRegression', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'LogisticRegression', 'accuracy': 0.6487514469985116, 'precision_true': array([0.58552898]), 'recall_true': array([0.97338275]), 'f1_score_true': array([0.73120729]), 'precision_false': array([0.92902066]), 'recall_false': array([0.33582332]), 'f1_score_false': array([0.49332061]), 'confussion_matrix': array([[1034,   79],
#        [2045, 2889]], dtype=int64)}, {'name': 'All_features__RandomForestClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'RandomForestClassifier', 'accuracy': 0.03026294030097569, 'precision_true': array([0.04975124]), 'recall_true': array([0.05390836]), 'f1_score_true': array([0.05174644]), 'precision_false': array([0.00812434]), 'recall_false': array([0.00746996]), 'f1_score_false': array([0.00778342]), 'confussion_matrix': array([[  23, 2808],
#        [3056,  160]], dtype=int64)}, {'name': 'All_features__SVC', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'SVC', 'accuracy': 0.5308417397056392, 'precision_true': array([0.51134592]), 'recall_true': array([0.99460916]), 'f1_score_true': array([0.67543759]), 'precision_false': array([0.94160584]), 'recall_false': array([0.08379344]), 'f1_score_false': array([0.15389204]), 'confussion_matrix': array([[ 258,   16],
#        [2821, 2952]], dtype=int64)}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.16811436844010133, 'precision_true': array([0.26038702]), 'recall_true': array([0.31410917]), 'f1_score_true': array([0.28473627]), 'precision_false': array([0.00695825]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.00605405]), 'confussion_matrix': array([[  14, 1998],
#        [2599,  915]], dtype=int64)}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.23307998552298226, 'precision_true': array([0.32894397]), 'recall_true': array([0.43734981]), 'f1_score_true': array([0.37547893]), 'precision_false': array([0.00846945]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.00656353]), 'confussion_matrix': array([[  14, 1639],
#        [2599, 1274]], dtype=int64)}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.04867897213174086, 'precision_true': array([0.08703312]), 'recall_true': array([0.08479231]), 'f1_score_true': array([0.0858981]), 'precision_false': array([0.00818452]), 'recall_false': array([0.00841944]), 'f1_score_false': array([0.00830032]), 'confussion_matrix': array([[  22, 2666],
#        [2591,  247]], dtype=int64)}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.16720955483170466, 'precision_true': array([0.25933314]), 'recall_true': array([0.31239272]), 'f1_score_true': array([0.28340081]), 'precision_false': array([0.006941]), 'recall_false': array([0.00535783]), 'f1_score_false': array([0.00604752]), 'confussion_matrix': array([[  14, 2003],
#        [2599,  910]], dtype=int64)}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.6954397394136808, 'precision_true': array([0.66932819]), 'recall_true': array([0.83453484]), 'f1_score_true': array([0.74285714]), 'precision_false': array([0.74551214]), 'recall_false': array([0.54037505]), 'f1_score_false': array([0.62658087]), 'confussion_matrix': array([[1412,  482],
#        [1201, 2431]], dtype=int64)}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.511943539630836, 'precision_true': array([0.52089783]), 'recall_true': array([0.9241332]), 'f1_score_true': array([0.66625418]), 'precision_false': array([0.38268156]), 'recall_false': array([0.05243016]), 'f1_score_false': array([0.09222484]), 'confussion_matrix': array([[ 137,  221],
#        [2476, 2692]], dtype=int64)}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.8845457835685848, 'precision_true': array([0.89870312]), 'recall_true': array([0.88019224]), 'f1_score_true': array([0.88935137]), 'precision_false': array([0.86943509]), 'recall_false': array([0.88939916]), 'f1_score_false': array([0.87930382]), 'confussion_matrix': array([[2324,  349],
#        [ 289, 2564]], dtype=int64)}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.511943539630836, 'precision_true': array([0.52101985]), 'recall_true': array([0.91898387]), 'f1_score_true': array([0.66501056]), 'precision_false': array([0.39175258]), 'recall_false': array([0.05817069]), 'f1_score_false': array([0.10129957]), 'confussion_matrix': array([[ 152,  236],
#        [2461, 2677]], dtype=int64)}, {'name': 'DESWLltd__DESPLd__KNeighborsClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.08161418747737965, 'precision_true': array([0.14370468]), 'recall_true': array([0.14967388]), 'f1_score_true': array([0.14662855]), 'precision_false': array([0.00601926]), 'recall_false': array([0.00574053]), 'f1_score_false': array([0.00587659]), 'confussion_matrix': array([[  15, 2477],
#        [2598,  436]], dtype=int64)}, {'name': 'DESWLltd__DESPLd__LogisticRegression', 'features': ['DESWLltd', 'DESPLd'], 'model': 'LogisticRegression', 'accuracy': 0.3123416576185306, 'precision_true': array([0.397219]), 'recall_true': array([0.58839684]), 'f1_score_true': array([0.47426674]), 'precision_false': array([0.00990917]), 'recall_false': array([0.00459242]), 'f1_score_false': array([0.00627615]), 'confussion_matrix': array([[  12, 1199],
#        [2601, 1714]], dtype=int64)}, {'name': 'DESWLltd__DESPLd__RandomForestClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'RandomForestClassifier', 'accuracy': 0.056098443720593555, 'precision_true': array([0.10114306]), 'recall_true': array([0.1002403]), 'f1_score_true': array([0.10068966]), 'precision_false': array([0.00682077]), 'recall_false': array([0.00688863]), 'f1_score_false': array([0.00685453]), 'confussion_matrix': array([[  18, 2621],
#        [2595,  292]], dtype=int64)}, {'name': 'DESWLltd__DESPLd__SVC', 'features': ['DESWLltd', 'DESPLd'], 'model': 'SVC', 'accuracy': 0.2077452044878755, 'precision_true': array([0.30398716]), 'recall_true': array([0.38997597]), 'f1_score_true': array([0.34165414]), 'precision_false': array([0.00670766]), 'recall_false': array([0.00459242]), 'f1_score_false': array([0.00545207]), 'confussion_matrix': array([[  12, 1777],
#        [2601, 1136]], dtype=int64)}, {'name': 'DESWLltd__KNeighborsClassifier', 'features': ['DESWLltd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.014375987361769352, 'precision_true': array([0.020625]), 'recall_true': array([0.02081362]), 'f1_score_true': array([0.02071888]), 'precision_false': array([0.00798722]), 'recall_false': array([0.0079139]), 'f1_score_false': array([0.00795039]), 'confussion_matrix': array([[  25, 3105],
#        [3134,   66]], dtype=int64)}, {'name': 'DESWLltd__LogisticRegression', 'features': ['DESWLltd'], 'model': 'LogisticRegression', 'accuracy': 0.07282780410742495, 'precision_true': array([0.12339475]), 'recall_true': array([0.13938821]), 'f1_score_true': array([0.13090478]), 'precision_false': array([0.00691412]), 'recall_false': array([0.00601456]), 'f1_score_false': array([0.00643305]), 'confussion_matrix': array([[  19, 2729],
#        [3140,  442]], dtype=int64)}, {'name': 'DESWLltd__RandomForestClassifier', 'features': ['DESWLltd'], 'model': 'RandomForestClassifier', 'accuracy': 0.02259083728278041, 'precision_true': array([0.02845528]), 'recall_true': array([0.02869757]), 'f1_score_true': array([0.02857591]), 'precision_false': array([0.01660281]), 'recall_false': array([0.01646091]), 'f1_score_false': array([0.01653155]), 'confussion_matrix': array([[  52, 3080],
#        [3107,   91]], dtype=int64)}, {'name': 'DESWLltd__SVC', 'features': ['DESWLltd'], 'model': 'SVC', 'accuracy': 0.0679304897314376, 'precision_true': array([0.1155255]), 'recall_true': array([0.12929675]), 'f1_score_true': array([0.12202381]), 'precision_false': array([0.00719166]), 'recall_false': array([0.00633112]), 'f1_score_false': array([0.00673401]), 'confussion_matrix': array([[  20, 2761],
#        [3139,  410]], dtype=int64)}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.02490482233502538, 'precision_true': array([0.03902137]), 'recall_true': array([0.03974763]), 'f1_score_true': array([0.03938115]), 'precision_false': array([0.0100813]), 'recall_false': array([0.00989151]), 'f1_score_false': array([0.0099855]), 'confussion_matrix': array([[  31, 3044],
#        [3103,  126]], dtype=int64)}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.03822969543147208, 'precision_true': array([0.06522393]), 'recall_true': array([0.06845426]), 'f1_score_true': array([0.06680006]), 'precision_false': array([0.00806181]), 'recall_false': array([0.00765795]), 'f1_score_false': array([0.00785469]), 'confussion_matrix': array([[  24, 2953],
#        [3110,  217]], dtype=int64)}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.016973350253807105, 'precision_true': array([0.02028526]), 'recall_true': array([0.02018927]), 'f1_score_true': array([0.02023715]), 'precision_false': array([0.01365513]), 'recall_false': array([0.01372049]), 'f1_score_false': array([0.01368773]), 'confussion_matrix': array([[  43, 3106],
#        [3091,   64]], dtype=int64)}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.04108502538071066, 'precision_true': array([0.07127945]), 'recall_true': array([0.07539432]), 'f1_score_true': array([0.07327917]), 'precision_false': array([0.00677736]), 'recall_false': array([0.00638162]), 'f1_score_false': array([0.00657354]), 'confussion_matrix': array([[  20, 2931],
#        [3114,  239]], dtype=int64)}]

# %% [markdown]
# do a mirror pair of models trained with this data and tested in the second dataset/fine tune

# %% [markdown]
# '''
#
# small crossvalidation to make sure model is stableand std bt the scores , lucky distr.
#
# data augmentation - + at the end with the generation model, feed the model with new elements
#
# method to input some text and see the prediction irt,
# automatically add fake news text to the data
#
#
# this is quant but we need qualitative
#
# SMOTE libary for DAug
#
# name of the file and template of the acl file - subsections things
#
# qualitative vs quantitative studies
#
# '''

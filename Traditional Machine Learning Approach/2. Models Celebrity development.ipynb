# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support


import pickle

from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %% [markdown]
# # Functions to create the models

# %% [markdown]
# These functions allow us to pass the training data and the set of features we want to train the models with to automatically make the models.

# %%
def data_preprocess(data):
  
  '''We input the data with the linguistic features
  and it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)
    data["Polarity"] = data["Polarity"].replace("True", 1)
    
    
  outcomes = ["Fake","Real"]
  
  return data, outcomes

def test_train(data, features):

  '''We input the training data and a list of the features we want to train the models with.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y = data["Polarity"] #outcomes 0 or 1


  print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  for feature in feature_cols:
    print(feature)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=16) #stratify so that the proportion of the train data is the same for fake and true

  return X, y, X_train, X_test, y_train, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores

def compare_models_cross_val(model, X, y):
  
  '''for each model, it calculates the cross validation accuracy for k-n
  as well as the mean cross validation score on the given data

  '''

  print("CROSS VALIDATION\n")

  model_name = str(model)[:-2]

  if model_name == "SVC(kernel=\'linear":

    model_name = "SVC"


  # for model in models:
  cv_score = cross_val_score(model, X, y, cv = 5)
  print("Cross validation accuracy {} for each of the 5 iterations:".format(model_name))
  for score in cv_score:
    print(round(score*100, 2), "%")

  mean_accuracy = sum(cv_score)/len(cv_score)

  print("\nCross validation mean accuracy for {}:".format(model_name), round(mean_accuracy*100, 2),"%")
  print("\n-------------------------------------------------------------------------\n")

  return cv_score, mean_accuracy

def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  if n_features == 1:

    plt.title("{} Confusion Matrix: {}".format(model_name, features[0]), y = 1.1)

  elif n_features == 2:

    plt.title("{} Confusion Matrix: {} and {}".format(model_name, features[0],features[1]), y = 1.1)

  elif n_features == 3:

    plt.title("{} Confusion Matrix: {}, {} and {}".format(model_name, features[0],features[1], features[2]), y = 1.1)

  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''

  model_list_dicts =[]

  for model in models:
    
    model_name = str(model)[:-2]

    if model_name == "SVC(kernel=\'linear":

      model_name = "SVC"
    
    model_dict = {}
    
    ft_str = str(features)[2:-2].replace("'","_").replace(",", "_").replace(" ", "_").replace("___", "_")
    
    model_dict["name"] = ft_str + "__" + model_name
    
    model_dict["features"] = features

    model_dict["model"] = model_name
    
    print("\n",model_name, "\n", "\n")
    
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    
    model_dict["accuracy"] = accuracy
    
    print("OVERALL ACCURACY", model_name, ":", round(accuracy*100, 2),"%""\n")
    
    scores = class_report(y_test, y_pred)
    
    P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
    precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]
    
    P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
    precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]
    
    model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
    model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

    cv_score, mean_accuracy = compare_models_cross_val(model, X, y)
    
    model_dict["cv_scores"] = cv_score

    model_dict["mean_cv_accuracy"] = mean_accuracy
    
    confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")
    
    model_dict["confussion_matrix"] = confussion_matrix
    
    model_dict["data_test_source"] = "training dataset"
    
    model_dict["training_normalized_together"] = "no"

    model_dict["testing_normalized_together"] = "no"

    model_list_dicts.append(model_dict)
    
    pickle.dump(model, open("Models\{}.sav".format(ft_str + "__" + model_name), 'wb'))
    
      
    with open("Models Performance\Training Celebrity dataset\{}.json".format(model_dict["name"]), "w") as f:
      json.dump(model_dict, f, cls=NumpyArrayEncoder)
  
  
  return model_list_dicts

def magic(data, features):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y, X_train, X_test, y_train, y_test, features = test_train(data, features) # data split for all the models with the desired features

  model_list_dicts = compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features) # for each model it will compute

  return model_list_dicts
# Out:
# <>:185: SyntaxWarning: invalid escape sequence '\{'
# <>:188: SyntaxWarning: invalid escape sequence '\T'
# <>:185: SyntaxWarning: invalid escape sequence '\{'
# <>:188: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\alber\AppData\Local\Temp\ipykernel_12976\3052351554.py:185: SyntaxWarning: invalid escape sequence '\{'
#   pickle.dump(model, open("Models\{}.sav".format(ft_str + "__" + model_name), 'wb'))
# C:\Users\alber\AppData\Local\Temp\ipykernel_12976\3052351554.py:188: SyntaxWarning: invalid escape sequence '\T'
#   with open("Models Performance\Training Celebrity dataset\{}.json".format(model_dict["name"]), "w") as f:

# %%
models = [LogisticRegression(), SVC(kernel ="linear"), KNeighborsClassifier(), RandomForestClassifier()]

# %%
list_set_features = [
['DESPC'],
['DESPC', 'DESPL', 'DESPLw', 'DESSL', 'SYNLE', 'SYNNP', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPC', 'DESPL', 'DESPLw', 'DESSL', 'SYNLE', 'SYNNP', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_PROPERTY_WRDHYPn', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPC', 'DESPL', 'DESPLw', 'DESSL', 'SYNLE', 'SYNNP', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPC', 'DESPL', 'DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_CNCAdd', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPC', 'DESPL', 'DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPC', 'DESSL'],
['DESPC', 'DESSL', 'READFKGL'],
['DESPC', 'DESSL', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPL', 'DESPLd', 'DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPL', 'DESPLd', 'DESPLw', 'DESSL', 'WORD_PROPERTY_WRDHYPn', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPL', 'DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPL', 'DESPLw', 'DESSL', 'WORD_PROPERTY_WRDHYPn', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPL', 'DESPLw', 'DESSL', 'WORD_PROPERTY_WRDHYPn', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPLd', 'DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
['DESPLd', 'WORD_PROPERTY_WRDHYPn'],
['DESPLw', 'DESSL', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESPLw', 'DESSL', 'SYNSTRUTa', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESWLltd'],
['DESWLltd', 'DESPLd'],
['DESWLltd', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'READFKGL', 'DESPLd', 'WORD_PROPERTY_WRDHYPn', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'],
['DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
['TOKEN_ATTRIBUTE_RATIO_ALHPA'], 
['TOKEN_ATTRIBUTE_RATIO_ALHPA', 'READFKGL', 'DESPLd', 'WORD_PROPERTY_WRDHYPn'],
['TOKEN_ATTRIBUTE_RATIO_ALHPA', 'READFKGL', 'DESPLd', 'WORD_PROPERTY_WRDHYPn', 'DESWLltd'], 
['TOKEN_ATTRIBUTE_RATIO_ALHPA', 'READFKGL', 'DESPLd', 'WORD_PROPERTY_WRDHYPn', 'DESWLltd', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS']]

# %% [markdown]
# # Loading training data

# %%
final_fts = pd.read_csv(r"Datasets\Celebrity Dataset\Celebrity_dataset_normalized.csv")
final_fts = final_fts.drop(labels="Unnamed: 0", axis=1)
print(final_fts.shape)
final_fts
# Out:
# (480, 63)
#         DESPC     DESSC     DESWC     DESPL    DESPLd    DESPLw     DESSL  \
# 0    0.444444  0.000000  0.146154  0.027027  0.000000  0.151143  0.682139
# 1    0.222222  0.176471  0.253846  0.148649  0.176471  0.201948  0.249849
# 2    0.222222  0.235294  0.276923  0.189189  0.235294  0.220999  0.191726
# 3    0.222222  0.176471  0.307692  0.148649  0.176471  0.240051  0.300706
# 4    0.222222  0.294118  0.296154  0.229730  0.294118  0.220999  0.147614
# ..        ...       ...       ...       ...       ...       ...       ...
# 475  0.222222  0.176471  0.296154  0.148649  0.176471  0.227350  0.289808
# 476  0.888889  0.117647  0.273077  0.010811  0.037203  0.053345  0.386983
# 477  0.444444  0.000000  0.130769  0.000000  0.048029  0.075642  0.645812
# 478  0.222222  0.470588  0.534615  0.351351  0.352941  0.337426  0.153582
# 479  0.222222  0.176471  0.138462  0.148649  0.058824  0.138442  0.140868
#
#        DESSLd   DESWLsy  DESWLsyd  ...  WORD_PROPERTY_WRDHYPn  \
# 0    0.000000  1.000000  0.563762  ...               0.404405
# 1    0.248429  0.109532  0.116088  ...               0.420646
# 2    0.215594  0.199330  0.134906  ...               0.561619
# 3    0.189370  0.191279  0.119235  ...               0.558820
# 4    0.110956  0.139367  0.084885  ...               0.666625
# ..        ...       ...       ...  ...                    ...
# 475  0.164698  0.264674  0.203276  ...               0.506349
# 476  0.384460  0.050249  0.047174  ...               0.455246
# 477  0.000000  0.370429  0.251662  ...               0.592211
# 478  0.189306  0.225581  0.206593  ...               0.492107
# 479  0.240751  0.445890  0.305984  ...               0.633193
#
#      WORD_PROPERTY_WRDHYPv  WORD_PROPERTY_WRDHYPnv  WORD_PROPERTY_AOA  \
# 0                 0.233333                0.363359           0.536598
# 1                 0.278947                0.072002           0.057090
# 2                 0.150980                0.439013           0.197521
# 3                 0.146154                0.479820           0.101196
# 4                 0.313333                0.399818           0.219840
# ..                     ...                     ...                ...
# 475               0.452381                0.532710           0.293080
# 476               0.119608                0.261489           0.097540
# 477               0.322222                0.538168           0.352350
# 478               0.056863                0.330483           0.095886
# 479               0.255556                0.476738           0.629851
#
#      WORD_PROPERTY_AOA_MAX  WORD_PROPERTY_CONCRETENESS  \
# 0                 0.396186                    0.393986
# 1                 0.309322                    0.612986
# 2                 0.297608                    0.685996
# 3                 0.147246                    0.814876
# 4                 0.617585                    0.218604
# ..                     ...                         ...
# 475               0.306847                    0.621988
# 476               0.323093                    0.499129
# 477               0.606992                    0.835890
# 478               0.423729                    0.532790
# 479               0.447034                    0.534365
#
#      WORD_PROPERTY_PREVALENCE  WORD_PROPERTY_PREVALENCE_MIN  \
# 0                    0.674648                      0.674648
# 1                    0.682585                      0.682585
# 2                    0.654967                      0.654967
# 3                    0.426085                      0.426085
# 4                    0.515320                      0.515320
# ..                        ...                           ...
# 475                  0.530017                      0.530017
# 476                  0.691053                      0.691053
# 477                  0.640981                      0.640981
# 478                  0.651265                      0.651265
# 479                  0.574802                      0.574802
#
#      WORD_SET_INCIDENCE_C4_COMMON_WORDS  Polarity
# 0                              0.685198      Fake
# 1                              0.252618      Fake
# 2                              0.546360      Fake
# 3                              0.367094      Fake
# 4                              0.550734      Fake
# ..                                  ...       ...
# 475                            0.516772      True
# 476                            0.339440      True
# 477                            0.230619      True
# 478                            0.156495      True
# 479                            0.268774      True
#
# [480 rows x 63 columns]

# %% [markdown]
# # Creating the 4 models for each set of features

# %%
# Creating the 4 models for each set of features

for features in list_set_features:
    
    model_final = magic(final_fts, features)
# Out:
# Info: 1 features were passed at the fit step
# :
# DESPC
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 53.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.53      0.55      0.54        60
#         Real       0.53      0.52      0.53        60
#
#     accuracy                           0.53       120
#    macro avg       0.53      0.53      0.53       120
# weighted avg       0.53      0.53      0.53       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 55.21 %
# 56.25 %
# 61.46 %
# 56.25 %
# 50.0 %
#
# Cross validation mean accuracy for LogisticRegression: 55.83 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.53      0.55      0.54        60
#         Real       0.53      0.52      0.53        60
#
#     accuracy                           0.53       120
#    macro avg       0.53      0.53      0.53       120
# weighted avg       0.53      0.53      0.53       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 55.21 %
# 56.25 %
# 61.46 %
# 56.25 %
# 50.0 %
#
# Cross validation mean accuracy for SVC: 55.83 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 76.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.94      0.57      0.71        60
#         Real       0.69      0.97      0.81        60
#
#     accuracy                           0.77       120
#    macro avg       0.82      0.77      0.76       120
# weighted avg       0.82      0.77      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 67.71 %
# 70.83 %
# 70.83 %
# 73.96 %
# 68.75 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 70.42 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 76.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.94      0.57      0.71        60
#         Real       0.69      0.97      0.81        60
#
#     accuracy                           0.77       120
#    macro avg       0.82      0.77      0.76       120
# weighted avg       0.82      0.77      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 72.92 %
# 75.0 %
# 71.88 %
# 78.12 %
# 78.12 %
#
# Cross validation mean accuracy for RandomForestClassifier: 75.21 %
#
# -------------------------------------------------------------------------
#
# Info: 12 features were passed at the fit step
# :
# DESPC
# DESPL
# DESPLw
# DESSL
# SYNLE
# SYNNP
# SYNSTRUTa
# RDFRE
# READFKGL
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 79.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.77      0.83      0.80        60
#         Real       0.82      0.75      0.78        60
#
#     accuracy                           0.79       120
#    macro avg       0.79      0.79      0.79       120
# weighted avg       0.79      0.79      0.79       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 75.0 %
# 78.12 %
# 75.0 %
# 73.96 %
# 70.83 %
#
# Cross validation mean accuracy for LogisticRegression: 74.58 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 76.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.74      0.82      0.78        60
#         Real       0.80      0.72      0.75        60
#
#     accuracy                           0.77       120
#    macro avg       0.77      0.77      0.77       120
# weighted avg       0.77      0.77      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 76.04 %
# 80.21 %
# 73.96 %
# 75.0 %
# 69.79 %
#
# Cross validation mean accuracy for SVC: 75.0 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 85.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.87      0.85        60
#         Real       0.86      0.83      0.85        60
#
#     accuracy                           0.85       120
#    macro avg       0.85      0.85      0.85       120
# weighted avg       0.85      0.85      0.85       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 73.96 %
# 83.33 %
# 79.17 %
# 83.33 %
# 84.38 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 80.83 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 88.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.87      0.90      0.89        60
#         Real       0.90      0.87      0.88        60
#
#     accuracy                           0.88       120
#    macro avg       0.88      0.88      0.88       120
# weighted avg       0.88      0.88      0.88       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 79.17 %
# 80.21 %
# 83.33 %
# 85.42 %
# 87.5 %
#
# Cross validation mean accuracy for RandomForestClassifier: 83.12 %
#
# -------------------------------------------------------------------------
#
# Info: 11 features were passed at the fit step
# :
# DESPC
# DESPL
# DESPLw
# DESSL
# SYNLE
# SYNNP
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_PROPERTY_WRDHYPn
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.78      0.75        60
#         Real       0.76      0.70      0.73        60
#
#     accuracy                           0.74       120
#    macro avg       0.74      0.74      0.74       120
# weighted avg       0.74      0.74      0.74       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 71.88 %
# 80.21 %
# 75.0 %
# 73.96 %
# 67.71 %
#
# Cross validation mean accuracy for LogisticRegression: 73.75 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 75.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.83      0.78        60
#         Real       0.80      0.68      0.74        60
#
#     accuracy                           0.76       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.76      0.76      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 71.88 %
# 79.17 %
# 73.96 %
# 75.0 %
# 70.83 %
#
# Cross validation mean accuracy for SVC: 74.17 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 81.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.78      0.81        60
#         Real       0.80      0.85      0.82        60
#
#     accuracy                           0.82       120
#    macro avg       0.82      0.82      0.82       120
# weighted avg       0.82      0.82      0.82       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 76.04 %
# 79.17 %
# 76.04 %
# 85.42 %
# 81.25 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 79.58 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 85.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.85      0.85      0.85        60
#         Real       0.85      0.85      0.85        60
#
#     accuracy                           0.85       120
#    macro avg       0.85      0.85      0.85       120
# weighted avg       0.85      0.85      0.85       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 81.25 %
# 79.17 %
# 79.17 %
# 83.33 %
# 84.38 %
#
# Cross validation mean accuracy for RandomForestClassifier: 81.46 %
#
# -------------------------------------------------------------------------
#
# Info: 11 features were passed at the fit step
# :
# DESPC
# DESPL
# DESPLw
# DESSL
# SYNLE
# SYNNP
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.80      0.76        60
#         Real       0.77      0.68      0.73        60
#
#     accuracy                           0.74       120
#    macro avg       0.75      0.74      0.74       120
# weighted avg       0.75      0.74      0.74       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 70.83 %
# 79.17 %
# 76.04 %
# 72.92 %
# 67.71 %
#
# Cross validation mean accuracy for LogisticRegression: 73.33 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 75.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.82      0.77        60
#         Real       0.79      0.70      0.74        60
#
#     accuracy                           0.76       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.76      0.76      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 70.83 %
# 77.08 %
# 76.04 %
# 77.08 %
# 71.88 %
#
# Cross validation mean accuracy for SVC: 74.58 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 79.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.82      0.75      0.78        60
#         Real       0.77      0.83      0.80        60
#
#     accuracy                           0.79       120
#    macro avg       0.79      0.79      0.79       120
# weighted avg       0.79      0.79      0.79       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 79.17 %
# 82.29 %
# 72.92 %
# 83.33 %
# 73.96 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 78.33 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 83.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.82      0.85      0.84        60
#         Real       0.84      0.82      0.83        60
#
#     accuracy                           0.83       120
#    macro avg       0.83      0.83      0.83       120
# weighted avg       0.83      0.83      0.83       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 83.33 %
# 82.29 %
# 79.17 %
# 83.33 %
# 87.5 %
#
# Cross validation mean accuracy for RandomForestClassifier: 83.12 %
#
# -------------------------------------------------------------------------
#
# Info: 10 features were passed at the fit step
# :
# DESPC
# DESPL
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_CNCAdd
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 75.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.83      0.78        60
#         Real       0.80      0.68      0.74        60
#
#     accuracy                           0.76       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.76      0.76      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 73.96 %
# 75.0 %
# 72.92 %
# 71.88 %
# 69.79 %
#
# Cross validation mean accuracy for LogisticRegression: 72.71 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 79.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.77      0.83      0.80        60
#         Real       0.82      0.75      0.78        60
#
#     accuracy                           0.79       120
#    macro avg       0.79      0.79      0.79       120
# weighted avg       0.79      0.79      0.79       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 73.96 %
# 77.08 %
# 70.83 %
# 76.04 %
# 75.0 %
#
# Cross validation mean accuracy for SVC: 74.58 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 85.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.85      0.87      0.86        60
#         Real       0.86      0.85      0.86        60
#
#     accuracy                           0.86       120
#    macro avg       0.86      0.86      0.86       120
# weighted avg       0.86      0.86      0.86       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 78.12 %
# 80.21 %
# 76.04 %
# 80.21 %
# 77.08 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 78.33 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 89.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.89      0.90      0.89        60
#         Real       0.90      0.88      0.89        60
#
#     accuracy                           0.89       120
#    macro avg       0.89      0.89      0.89       120
# weighted avg       0.89      0.89      0.89       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 84.38 %
# 79.17 %
# 78.12 %
# 83.33 %
# 83.33 %
#
# Cross validation mean accuracy for RandomForestClassifier: 81.67 %
#
# -------------------------------------------------------------------------
#
# Info: 9 features were passed at the fit step
# :
# DESPC
# DESPL
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 72.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.80      0.74        60
#         Real       0.76      0.65      0.70        60
#
#     accuracy                           0.73       120
#    macro avg       0.73      0.73      0.72       120
# weighted avg       0.73      0.72      0.72       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 69.79 %
# 76.04 %
# 77.08 %
# 69.79 %
# 63.54 %
#
# Cross validation mean accuracy for LogisticRegression: 71.25 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 75.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.87      0.78        60
#         Real       0.83      0.63      0.72        60
#
#     accuracy                           0.75       120
#    macro avg       0.76      0.75      0.75       120
# weighted avg       0.76      0.75      0.75       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 70.83 %
# 69.79 %
# 77.08 %
# 70.83 %
# 68.75 %
#
# Cross validation mean accuracy for SVC: 71.46 %
#
# -------------------------------------------------------------------------
# C:\Users\alber\AppData\Local\Temp\ipykernel_12976\3052351554.py:91: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 85.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.87      0.85        60
#         Real       0.86      0.83      0.85        60
#
#     accuracy                           0.85       120
#    macro avg       0.85      0.85      0.85       120
# weighted avg       0.85      0.85      0.85       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 72.92 %
# 78.12 %
# 73.96 %
# 80.21 %
# 75.0 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 76.04 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 83.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.81      0.87      0.84        60
#         Real       0.86      0.80      0.83        60
#
#     accuracy                           0.83       120
#    macro avg       0.83      0.83      0.83       120
# weighted avg       0.83      0.83      0.83       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 81.25 %
# 78.12 %
# 77.08 %
# 83.33 %
# 84.38 %
#
# Cross validation mean accuracy for RandomForestClassifier: 80.83 %
#
# -------------------------------------------------------------------------
#
# Info: 2 features were passed at the fit step
# :
# DESPC
# DESSL
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.55      0.56        60
#         Real       0.57      0.60      0.59        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 62.5 %
# 61.46 %
# 63.54 %
# 59.38 %
# 57.29 %
#
# Cross validation mean accuracy for LogisticRegression: 60.83 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 69.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.66      0.80      0.72        60
#         Real       0.74      0.58      0.65        60
#
#     accuracy                           0.69       120
#    macro avg       0.70      0.69      0.69       120
# weighted avg       0.70      0.69      0.69       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 62.5 %
# 69.79 %
# 72.92 %
# 68.75 %
# 65.62 %
#
# Cross validation mean accuracy for SVC: 67.92 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.76      0.70      0.73        60
#         Real       0.72      0.78      0.75        60
#
#     accuracy                           0.74       120
#    macro avg       0.74      0.74      0.74       120
# weighted avg       0.74      0.74      0.74       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 72.92 %
# 79.17 %
# 68.75 %
# 70.83 %
# 79.17 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 74.17 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 72.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.76      0.65      0.70        60
#         Real       0.70      0.80      0.74        60
#
#     accuracy                           0.73       120
#    macro avg       0.73      0.73      0.72       120
# weighted avg       0.73      0.72      0.72       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 75.0 %
# 73.96 %
# 71.88 %
# 70.83 %
# 75.0 %
#
# Cross validation mean accuracy for RandomForestClassifier: 73.33 %
#
# -------------------------------------------------------------------------
#
# Info: 3 features were passed at the fit step
# :
# DESPC
# DESSL
# READFKGL
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.55      0.56        60
#         Real       0.57      0.60      0.59        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 60.42 %
# 60.42 %
# 62.5 %
# 61.46 %
# 58.33 %
#
# Cross validation mean accuracy for LogisticRegression: 60.62 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 69.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.65      0.82      0.73        60
#         Real       0.76      0.57      0.65        60
#
#     accuracy                           0.69       120
#    macro avg       0.70      0.69      0.69       120
# weighted avg       0.70      0.69      0.69       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 63.54 %
# 69.79 %
# 70.83 %
# 67.71 %
# 66.67 %
#
# Cross validation mean accuracy for SVC: 67.71 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 75.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.79      0.70      0.74        60
#         Real       0.73      0.82      0.77        60
#
#     accuracy                           0.76       120
#    macro avg       0.76      0.76      0.76       120
# weighted avg       0.76      0.76      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 68.75 %
# 70.83 %
# 65.62 %
# 76.04 %
# 78.12 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 71.88 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 72.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.67      0.71        60
#         Real       0.70      0.78      0.74        60
#
#     accuracy                           0.73       120
#    macro avg       0.73      0.72      0.72       120
# weighted avg       0.73      0.72      0.72       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 71.88 %
# 67.71 %
# 71.88 %
# 80.21 %
# 70.83 %
#
# Cross validation mean accuracy for RandomForestClassifier: 72.5 %
#
# -------------------------------------------------------------------------
#
# Info: 4 features were passed at the fit step
# :
# DESPC
# DESSL
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 71.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.78      0.73        60
#         Real       0.75      0.65      0.70        60
#
#     accuracy                           0.72       120
#    macro avg       0.72      0.72      0.72       120
# weighted avg       0.72      0.72      0.72       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 67.71 %
# 71.88 %
# 73.96 %
# 69.79 %
# 64.58 %
#
# Cross validation mean accuracy for LogisticRegression: 69.58 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 73.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.83      0.76        60
#         Real       0.79      0.63      0.70        60
#
#     accuracy                           0.73       120
#    macro avg       0.74      0.73      0.73       120
# weighted avg       0.74      0.73      0.73       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 68.75 %
# 72.92 %
# 77.08 %
# 71.88 %
# 67.71 %
#
# Cross validation mean accuracy for SVC: 71.67 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 79.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.79      0.80      0.79        60
#         Real       0.80      0.78      0.79        60
#
#     accuracy                           0.79       120
#    macro avg       0.79      0.79      0.79       120
# weighted avg       0.79      0.79      0.79       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 75.0 %
# 83.33 %
# 72.92 %
# 79.17 %
# 79.17 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 77.92 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 80.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.78      0.83      0.81        60
#         Real       0.82      0.77      0.79        60
#
#     accuracy                           0.80       120
#    macro avg       0.80      0.80      0.80       120
# weighted avg       0.80      0.80      0.80       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 81.25 %
# 76.04 %
# 73.96 %
# 79.17 %
# 86.46 %
#
# Cross validation mean accuracy for RandomForestClassifier: 79.38 %
#
# -------------------------------------------------------------------------
#
# Info: 8 features were passed at the fit step
# :
# DESPL
# DESPLd
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.62      0.67        53
#         Real       0.70      0.78      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 65.56 %
# 70.0 %
# 68.89 %
# 67.78 %
# 71.11 %
#
# Cross validation mean accuracy for LogisticRegression: 68.67 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.64      0.67        53
#         Real       0.71      0.77      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 67.78 %
# 65.56 %
# 68.89 %
# 67.78 %
# 73.33 %
#
# Cross validation mean accuracy for SVC: 68.67 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 72.57 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.70      0.70        53
#         Real       0.74      0.75      0.74        60
#
#     accuracy                           0.73       113
#    macro avg       0.72      0.72      0.72       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 66.67 %
# 66.67 %
# 68.89 %
# 71.11 %
# 75.56 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 69.78 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 75.22 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.75      0.74        53
#         Real       0.78      0.75      0.76        60
#
#     accuracy                           0.75       113
#    macro avg       0.75      0.75      0.75       113
# weighted avg       0.75      0.75      0.75       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 73.33 %
# 66.67 %
# 73.33 %
# 76.67 %
# 82.22 %
#
# Cross validation mean accuracy for RandomForestClassifier: 74.44 %
#
# -------------------------------------------------------------------------
#
# Info: 9 features were passed at the fit step
# :
# DESPL
# DESPLd
# DESPLw
# DESSL
# WORD_PROPERTY_WRDHYPn
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 69.91 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.60      0.65        53
#         Real       0.69      0.78      0.73        60
#
#     accuracy                           0.70       113
#    macro avg       0.70      0.69      0.69       113
# weighted avg       0.70      0.70      0.70       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 67.78 %
# 72.22 %
# 65.56 %
# 66.67 %
# 70.0 %
#
# Cross validation mean accuracy for LogisticRegression: 68.44 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.64      0.67        53
#         Real       0.71      0.77      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 63.33 %
# 67.78 %
# 64.44 %
# 66.67 %
# 73.33 %
#
# Cross validation mean accuracy for SVC: 67.11 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 66.37 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.65      0.62      0.63        53
#         Real       0.68      0.70      0.69        60
#
#     accuracy                           0.66       113
#    macro avg       0.66      0.66      0.66       113
# weighted avg       0.66      0.66      0.66       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 68.89 %
# 62.22 %
# 65.56 %
# 72.22 %
# 74.44 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 68.67 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 74.34 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.72      0.72        53
#         Real       0.75      0.77      0.76        60
#
#     accuracy                           0.74       113
#    macro avg       0.74      0.74      0.74       113
# weighted avg       0.74      0.74      0.74       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 73.33 %
# 72.22 %
# 76.67 %
# 80.0 %
# 78.89 %
#
# Cross validation mean accuracy for RandomForestClassifier: 76.22 %
#
# -------------------------------------------------------------------------
#
# Info: 8 features were passed at the fit step
# :
# DESPL
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.85      0.77        60
#         Real       0.81      0.63      0.71        60
#
#     accuracy                           0.74       120
#    macro avg       0.75      0.74      0.74       120
# weighted avg       0.75      0.74      0.74       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 68.75 %
# 67.71 %
# 69.79 %
# 65.62 %
# 73.96 %
#
# Cross validation mean accuracy for LogisticRegression: 69.17 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.85      0.77        60
#         Real       0.81      0.63      0.71        60
#
#     accuracy                           0.74       120
#    macro avg       0.75      0.74      0.74       120
# weighted avg       0.75      0.74      0.74       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 67.71 %
# 69.79 %
# 70.83 %
# 67.71 %
# 75.0 %
#
# Cross validation mean accuracy for SVC: 70.21 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 78.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.77      0.82      0.79        60
#         Real       0.80      0.75      0.78        60
#
#     accuracy                           0.78       120
#    macro avg       0.78      0.78      0.78       120
# weighted avg       0.78      0.78      0.78       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 73.96 %
# 69.79 %
# 72.92 %
# 81.25 %
# 69.79 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 73.54 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 76.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.85      0.78        60
#         Real       0.82      0.68      0.75        60
#
#     accuracy                           0.77       120
#    macro avg       0.77      0.77      0.77       120
# weighted avg       0.77      0.77      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 77.08 %
# 67.71 %
# 75.0 %
# 79.17 %
# 80.21 %
#
# Cross validation mean accuracy for RandomForestClassifier: 75.83 %
#
# -------------------------------------------------------------------------
#
# Info: 8 features were passed at the fit step
# :
# DESPL
# DESPLw
# DESSL
# WORD_PROPERTY_WRDHYPn
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 75.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.85      0.77        60
#         Real       0.81      0.65      0.72        60
#
#     accuracy                           0.75       120
#    macro avg       0.76      0.75      0.75       120
# weighted avg       0.76      0.75      0.75       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 67.71 %
# 69.79 %
# 67.71 %
# 67.71 %
# 78.12 %
#
# Cross validation mean accuracy for LogisticRegression: 70.21 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 76.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.87      0.79        60
#         Real       0.83      0.67      0.74        60
#
#     accuracy                           0.77       120
#    macro avg       0.78      0.77      0.76       120
# weighted avg       0.78      0.77      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 67.71 %
# 72.92 %
# 65.62 %
# 68.75 %
# 79.17 %
#
# Cross validation mean accuracy for SVC: 70.83 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 65.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.72      0.68        60
#         Real       0.68      0.60      0.64        60
#
#     accuracy                           0.66       120
#    macro avg       0.66      0.66      0.66       120
# weighted avg       0.66      0.66      0.66       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 70.83 %
# 68.75 %
# 65.62 %
# 72.92 %
# 68.75 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 69.38 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 77.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.82      0.78        60
#         Real       0.80      0.73      0.77        60
#
#     accuracy                           0.78       120
#    macro avg       0.78      0.77      0.77       120
# weighted avg       0.78      0.78      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 71.88 %
# 70.83 %
# 73.96 %
# 76.04 %
# 79.17 %
#
# Cross validation mean accuracy for RandomForestClassifier: 74.38 %
#
# -------------------------------------------------------------------------
#
# Info: 9 features were passed at the fit step
# :
# DESPL
# DESPLw
# DESSL
# WORD_PROPERTY_WRDHYPn
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 75.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.85      0.78        60
#         Real       0.82      0.67      0.73        60
#
#     accuracy                           0.76       120
#    macro avg       0.77      0.76      0.76       120
# weighted avg       0.77      0.76      0.76       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 67.71 %
# 68.75 %
# 67.71 %
# 64.58 %
# 78.12 %
#
# Cross validation mean accuracy for LogisticRegression: 69.38 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 77.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.87      0.79        60
#         Real       0.84      0.68      0.75        60
#
#     accuracy                           0.78       120
#    macro avg       0.78      0.78      0.77       120
# weighted avg       0.78      0.78      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 67.71 %
# 73.96 %
# 65.62 %
# 66.67 %
# 77.08 %
#
# Cross validation mean accuracy for SVC: 70.21 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 77.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.78      0.77      0.77        60
#         Real       0.77      0.78      0.78        60
#
#     accuracy                           0.78       120
#    macro avg       0.78      0.78      0.77       120
# weighted avg       0.78      0.78      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 66.67 %
# 65.62 %
# 70.83 %
# 76.04 %
# 69.79 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 69.79 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 77.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.83      0.79        60
#         Real       0.81      0.72      0.76        60
#
#     accuracy                           0.78       120
#    macro avg       0.78      0.78      0.77       120
# weighted avg       0.78      0.78      0.77       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 72.92 %
# 70.83 %
# 77.08 %
# 76.04 %
# 78.12 %
#
# Cross validation mean accuracy for RandomForestClassifier: 75.0 %
#
# -------------------------------------------------------------------------
#
# Info: 7 features were passed at the fit step
# :
# DESPLd
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.62      0.67        53
#         Real       0.70      0.78      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 65.56 %
# 70.0 %
# 67.78 %
# 66.67 %
# 71.11 %
#
# Cross validation mean accuracy for LogisticRegression: 68.22 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.64      0.67        53
#         Real       0.71      0.77      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 68.89 %
# 68.89 %
# 68.89 %
# 67.78 %
# 73.33 %
#
# Cross validation mean accuracy for SVC: 69.56 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 73.45 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.70      0.71        53
#         Real       0.74      0.77      0.75        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.73      0.73       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 68.89 %
# 66.67 %
# 70.0 %
# 74.44 %
# 75.56 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 71.11 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 76.99 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.78      0.72      0.75        53
#         Real       0.77      0.82      0.79        60
#
#     accuracy                           0.77       113
#    macro avg       0.77      0.77      0.77       113
# weighted avg       0.77      0.77      0.77       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 73.33 %
# 66.67 %
# 73.33 %
# 81.11 %
# 80.0 %
#
# Cross validation mean accuracy for RandomForestClassifier: 74.89 %
#
# -------------------------------------------------------------------------
#
# Info: 3 features were passed at the fit step
# :
# DESPLd
# DESWLltd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.52 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.60      0.28      0.38        53
#         Real       0.57      0.83      0.68        60
#
#     accuracy                           0.58       113
#    macro avg       0.58      0.56      0.53       113
# weighted avg       0.58      0.58      0.54       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 56.67 %
# 54.44 %
# 55.56 %
# 58.89 %
# 54.44 %
#
# Cross validation mean accuracy for LogisticRegression: 56.0 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.1 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.08      0.13        53
#         Real       0.53      0.93      0.68        60
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.50      0.40       113
# weighted avg       0.52      0.53      0.42       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 57.78 %
# 54.44 %
# 53.33 %
# 57.78 %
# 52.22 %
#
# Cross validation mean accuracy for SVC: 55.11 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 59.29 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.49      0.53        53
#         Real       0.60      0.68      0.64        60
#
#     accuracy                           0.59       113
#    macro avg       0.59      0.59      0.59       113
# weighted avg       0.59      0.59      0.59       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 61.11 %
# 63.33 %
# 63.33 %
# 57.78 %
# 66.67 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 62.44 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 63.72 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.62      0.58      0.60        53
#         Real       0.65      0.68      0.67        60
#
#     accuracy                           0.64       113
#    macro avg       0.64      0.63      0.63       113
# weighted avg       0.64      0.64      0.64       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 65.56 %
# 57.78 %
# 58.89 %
# 66.67 %
# 61.11 %
#
# Cross validation mean accuracy for RandomForestClassifier: 62.0 %
#
# -------------------------------------------------------------------------
#
# Info: 2 features were passed at the fit step
# :
# DESPLd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 59.29 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.32      0.42        53
#         Real       0.58      0.83      0.68        60
#
#     accuracy                           0.59       113
#    macro avg       0.61      0.58      0.55       113
# weighted avg       0.60      0.59      0.56       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 56.67 %
# 52.22 %
# 55.56 %
# 60.0 %
# 56.67 %
#
# Cross validation mean accuracy for LogisticRegression: 56.22 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.1 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.02      0.04        53
#         Real       0.53      0.98      0.69        60
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.50      0.36       113
# weighted avg       0.52      0.53      0.38       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 56.67 %
# 53.33 %
# 55.56 %
# 56.67 %
# 52.22 %
#
# Cross validation mean accuracy for SVC: 54.89 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 58.41 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.56      0.53      0.54        53
#         Real       0.60      0.63      0.62        60
#
#     accuracy                           0.58       113
#    macro avg       0.58      0.58      0.58       113
# weighted avg       0.58      0.58      0.58       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 66.67 %
# 65.56 %
# 62.22 %
# 56.67 %
# 60.0 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 62.22 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 64.6 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.55      0.59        53
#         Real       0.65      0.73      0.69        60
#
#     accuracy                           0.65       113
#    macro avg       0.65      0.64      0.64       113
# weighted avg       0.65      0.65      0.64       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 62.22 %
# 62.22 %
# 66.67 %
# 63.33 %
# 61.11 %
#
# Cross validation mean accuracy for RandomForestClassifier: 63.11 %
#
# -------------------------------------------------------------------------
#
# Info: 6 features were passed at the fit step
# :
# DESPLw
# DESSL
# SYNSTRUTa
# RDFRE
# READFKGL
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 74.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.85      0.77        60
# ...
# 74.44 %
# 78.89 %
# 71.11 %
# 66.67 %
# 74.44 %
#
# Cross validation mean accuracy for LogisticRegression: 73.11 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 72.57 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.68      0.70        53
#         Real       0.73      0.77      0.75        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.72      0.72       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 74.44 %
# 76.67 %
# 68.89 %
# 65.56 %
# 74.44 %
#
# Cross validation mean accuracy for SVC: 72.0 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 69.03 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.62      0.65        53
#         Real       0.69      0.75      0.72        60
#
#     accuracy                           0.69       113
#    macro avg       0.69      0.69      0.69       113
# weighted avg       0.69      0.69      0.69       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 70.0 %
# 72.22 %
# 72.22 %
# 66.67 %
# 65.56 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 69.33 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 72.57 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.68      0.70        53
#         Real       0.73      0.77      0.75        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.72      0.72       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 76.67 %
# 68.89 %
# 73.33 %
# 68.89 %
# 74.44 %
#
# Cross validation mean accuracy for RandomForestClassifier: 72.44 %
#
# -------------------------------------------------------------------------
#
# Info: 2 features were passed at the fit step
# :
# DESWLltd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.55      0.56        60
#         Real       0.57      0.60      0.59        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 58.33 %
# 60.42 %
# 59.38 %
# 46.88 %
# 63.54 %
#
# Cross validation mean accuracy for LogisticRegression: 57.71 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 50.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.65      0.57        60
#         Real       0.50      0.35      0.41        60
#
#     accuracy                           0.50       120
#    macro avg       0.50      0.50      0.49       120
# weighted avg       0.50      0.50      0.49       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 56.25 %
# 63.54 %
# 58.33 %
# 44.79 %
# 50.0 %
#
# Cross validation mean accuracy for SVC: 54.58 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 51.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.52      0.47      0.49        60
#         Real       0.52      0.57      0.54        60
#
#     accuracy                           0.52       120
#    macro avg       0.52      0.52      0.52       120
# weighted avg       0.52      0.52      0.52       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 52.08 %
# 55.21 %
# 46.88 %
# 50.0 %
# 53.12 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 51.46 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 49.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.49      0.45      0.47        60
#         Real       0.49      0.53      0.51        60
#
#     accuracy                           0.49       120
#    macro avg       0.49      0.49      0.49       120
# weighted avg       0.49      0.49      0.49       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 55.21 %
# 50.0 %
# 46.88 %
# 55.21 %
# 51.04 %
#
# Cross validation mean accuracy for RandomForestClassifier: 51.67 %
#
# -------------------------------------------------------------------------
#
# Info: 1 features were passed at the fit step
# :
# TOKEN_ATTRIBUTE_RATIO_ALHPA
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 61.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.67      0.63        60
#         Real       0.63      0.57      0.60        60
#
#     accuracy                           0.62       120
#    macro avg       0.62      0.62      0.62       120
# weighted avg       0.62      0.62      0.62       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 63.54 %
# 65.62 %
# 61.46 %
# 60.42 %
# 59.38 %
#
# Cross validation mean accuracy for LogisticRegression: 62.08 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 64.17 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.67      0.65        60
#         Real       0.65      0.62      0.63        60
#
#     accuracy                           0.64       120
#    macro avg       0.64      0.64      0.64       120
# weighted avg       0.64      0.64      0.64       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 64.58 %
# 63.54 %
# 62.5 %
# 60.42 %
# 59.38 %
#
# Cross validation mean accuracy for SVC: 62.08 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.57      0.60      0.59        60
#         Real       0.58      0.55      0.56        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 58.33 %
# 58.33 %
# 67.71 %
# 61.46 %
# 56.25 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 60.42 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 60.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.60      0.63      0.62        60
#         Real       0.61      0.58      0.60        60
#
#     accuracy                           0.61       120
#    macro avg       0.61      0.61      0.61       120
# weighted avg       0.61      0.61      0.61       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 59.38 %
# 60.42 %
# 63.54 %
# 62.5 %
# 52.08 %
#
# Cross validation mean accuracy for RandomForestClassifier: 59.58 %
#
# -------------------------------------------------------------------------
#
# Info: 4 features were passed at the fit step
# :
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# READFKGL
# DESPLd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 69.91 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.66      0.67        53
#         Real       0.71      0.73      0.72        60
#
#     accuracy                           0.70       113
#    macro avg       0.70      0.70      0.70       113
# weighted avg       0.70      0.70      0.70       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 71.11 %
# 74.44 %
# 70.0 %
# 70.0 %
# 66.67 %
#
# Cross validation mean accuracy for LogisticRegression: 70.44 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.67      0.74      0.70        53
#         Real       0.75      0.68      0.71        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.71      0.71       113
# weighted avg       0.71      0.71      0.71       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 71.11 %
# 70.0 %
# 68.89 %
# 68.89 %
# 66.67 %
#
# Cross validation mean accuracy for SVC: 69.11 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 65.49 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.72      0.66        53
#         Real       0.71      0.60      0.65        60
#
#     accuracy                           0.65       113
#    macro avg       0.66      0.66      0.65       113
# weighted avg       0.66      0.65      0.65       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 71.11 %
# 66.67 %
# 63.33 %
# 66.67 %
# 66.67 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 66.89 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 73.45 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.71      0.74      0.72        53
#         Real       0.76      0.73      0.75        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.73      0.73       113
# weighted avg       0.74      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 73.33 %
# 67.78 %
# 74.44 %
# 77.78 %
# 70.0 %
#
# Cross validation mean accuracy for RandomForestClassifier: 72.67 %
#
# -------------------------------------------------------------------------
#
# Info: 5 features were passed at the fit step
# :
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# READFKGL
# DESPLd
# WORD_PROPERTY_WRDHYPn
# DESWLltd
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 69.91 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.66      0.67        53
#         Real       0.71      0.73      0.72        60
#
#     accuracy                           0.70       113
#    macro avg       0.70      0.70      0.70       113
# weighted avg       0.70      0.70      0.70       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 70.0 %
# 74.44 %
# 70.0 %
# 70.0 %
# 66.67 %
#
# Cross validation mean accuracy for LogisticRegression: 70.22 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 68.14 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.74      0.68        53
#         Real       0.73      0.63      0.68        60
#
#     accuracy                           0.68       113
#    macro avg       0.69      0.68      0.68       113
# weighted avg       0.69      0.68      0.68       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 71.11 %
# 70.0 %
# 68.89 %
# 68.89 %
# 66.67 %
#
# Cross validation mean accuracy for SVC: 69.11 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 62.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.59      0.66      0.62        53
#         Real       0.67      0.60      0.63        60
#
#     accuracy                           0.63       113
#    macro avg       0.63      0.63      0.63       113
# weighted avg       0.63      0.63      0.63       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 68.89 %
# 70.0 %
# 64.44 %
# 66.67 %
# 64.44 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 66.89 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 75.22 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.81      0.75        53
#         Real       0.81      0.70      0.75        60
#
#     accuracy                           0.75       113
#    macro avg       0.76      0.76      0.75       113
# weighted avg       0.76      0.75      0.75       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 82.22 %
# 66.67 %
# 74.44 %
# 72.22 %
# 80.0 %
#
# Cross validation mean accuracy for RandomForestClassifier: 75.11 %
#
# -------------------------------------------------------------------------
#
# Info: 6 features were passed at the fit step
# :
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# READFKGL
# DESPLd
# WORD_PROPERTY_WRDHYPn
# DESWLltd
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 70.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.60      0.66        53
#         Real       0.70      0.80      0.74        60
#
#     accuracy                           0.71       113
#    macro avg       0.71      0.70      0.70       113
# weighted avg       0.71      0.71      0.70       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 74.44 %
# 78.89 %
# 71.11 %
# 66.67 %
# 74.44 %
#
# Cross validation mean accuracy for LogisticRegression: 73.11 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 72.57 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.72      0.68      0.70        53
#         Real       0.73      0.77      0.75        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.72      0.72       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 74.44 %
# 76.67 %
# 68.89 %
# 65.56 %
# 74.44 %
#
# Cross validation mean accuracy for SVC: 72.0 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 69.03 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.62      0.65        53
#         Real       0.69      0.75      0.72        60
#
#     accuracy                           0.69       113
#    macro avg       0.69      0.69      0.69       113
# weighted avg       0.69      0.69      0.69       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 70.0 %
# 72.22 %
# 72.22 %
# 66.67 %
# 65.56 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 69.33 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 73.45 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.73      0.68      0.71        53
#         Real       0.73      0.78      0.76        60
#
#     accuracy                           0.73       113
#    macro avg       0.73      0.73      0.73       113
# weighted avg       0.73      0.73      0.73       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 78.89 %
# 67.78 %
# 73.33 %
# 67.78 %
# 73.33 %
#
# Cross validation mean accuracy for RandomForestClassifier: 72.22 %
#
# -------------------------------------------------------------------------

# %% [markdown]
# #Models with the set of all available features

# %% [markdown]
# Slightly modified version of the aforementioned functions to create the four models with the set of all available features.

# %% [markdown]
# These functions allow us to pass the training data and the set of features we want to train the models with to automatically make the models.

# %%
def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)
    data["Polarity"] = data["Polarity"].replace("True", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def test_train(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y = data["Polarity"] #outcomes 0 or 1


  print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  for feature in feature_cols:
    print(feature)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=16) #stratify so that the proportion of the train data is the same for fake and true

  return X, y, X_train, X_test, y_train, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores

def compare_models_cross_val(model, X, y):
  
  '''for each model, it calculates the cross validation accuracy for each iteration
  as well as the mean cross validation score on the given data

  '''

  print("CROSS VALIDATION\n")

  model_name = str(model)[:-2]

  if model_name == "SVC(kernel=\'linear":

    model_name = "SVC"


  # for model in models:
  cv_score = cross_val_score(model, X, y, cv = 5)
  print("Cross validation accuracy {} for each of the 5 iterations:".format(model_name))
  for score in cv_score:
    print(round(score*100, 2), "%")

  mean_accuracy = sum(cv_score)/len(cv_score)

  print("\nCross validation mean accuracy for {}:".format(model_name), round(mean_accuracy*100, 2),"%")
  print("\n-------------------------------------------------------------------------\n")

  return cv_score, mean_accuracy

def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  
  plt.title("{} Confusion Matrix: All available features".format(model_name), y = 1.1)


  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''

  model_list_dicts =[]

  for model in models:
    
    model_name = str(model)[:-2]

    if model_name == "SVC(kernel=\'linear":

      model_name = "SVC"
    
    model_dict = {}
    
    model_dict["name"] = "All_features__" + model_name
    
    model_dict["features"] = features

    model_dict["model"] = model_name
    
    print("\n",model_name, "\n", "\n")
    
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    
    model_dict["accuracy"] = accuracy
    
    print("OVERALL ACCURACY", model_name, ":", round(accuracy*100, 2),"%""\n")
    
    scores = class_report(y_test, y_pred)
    
    P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
    precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]
    
    P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
    precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]
    
    model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
    model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

    cv_score, mean_accuracy = compare_models_cross_val(model, X, y)
    
    model_dict["cv_scores"] = cv_score

    model_dict["mean_cv_accuracy"] = mean_accuracy
    
    confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")
    
    model_dict["confussion_matrix"] = confussion_matrix

    model_dict["data_test_source"] = "training dataset"
    
    model_dict["training_normalized_together"] = "no"

    model_dict["testing_normalized_together"] = "no"

    model_list_dicts.append(model_dict)
    
    pickle.dump(model, open(r"Models\{}.sav".format(model_dict["name"]), 'wb'))
    
      
    with open(r"Models Performance\Training Celebrity dataset\{}.json".format(model_dict["name"]), "w") as f:
      json.dump(model_dict, f, cls=NumpyArrayEncoder)
  
  
  return model_list_dicts

def magic(data, features):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross validation evaluation and the confusion matrix

  '''

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y, X_train, X_test, y_train, y_test, features = test_train(data, features) # data split for all the models with the desired features

  model_list_dicts = compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features) # for each model it will compute

  return model_list_dicts

# %%
all_fts = pd.read_csv(r"Datasets\Celebrity Dataset\Celebrity_dataset_normalized.csv")

# %%
all_fts = all_fts.drop(labels="Unnamed: 0", axis=1)
print(all_fts.shape)
all_fts
# Out:
# (480, 63)
#         DESPC     DESSC     DESWC     DESPL    DESPLd    DESPLw     DESSL  \
# 0    0.444444  0.000000  0.146154  0.027027  0.000000  0.151143  0.682139
# 1    0.222222  0.176471  0.253846  0.148649  0.176471  0.201948  0.249849
# 2    0.222222  0.235294  0.276923  0.189189  0.235294  0.220999  0.191726
# 3    0.222222  0.176471  0.307692  0.148649  0.176471  0.240051  0.300706
# 4    0.222222  0.294118  0.296154  0.229730  0.294118  0.220999  0.147614
# ..        ...       ...       ...       ...       ...       ...       ...
# 475  0.222222  0.176471  0.296154  0.148649  0.176471  0.227350  0.289808
# 476  0.888889  0.117647  0.273077  0.010811  0.037203  0.053345  0.386983
# 477  0.444444  0.000000  0.130769  0.000000  0.048029  0.075642  0.645812
# 478  0.222222  0.470588  0.534615  0.351351  0.352941  0.337426  0.153582
# 479  0.222222  0.176471  0.138462  0.148649  0.058824  0.138442  0.140868
#
#        DESSLd   DESWLsy  DESWLsyd  ...  WORD_PROPERTY_WRDHYPn  \
# 0    0.000000  1.000000  0.563762  ...               0.404405
# 1    0.248429  0.109532  0.116088  ...               0.420646
# 2    0.215594  0.199330  0.134906  ...               0.561619
# 3    0.189370  0.191279  0.119235  ...               0.558820
# 4    0.110956  0.139367  0.084885  ...               0.666625
# ..        ...       ...       ...  ...                    ...
# 475  0.164698  0.264674  0.203276  ...               0.506349
# 476  0.384460  0.050249  0.047174  ...               0.455246
# 477  0.000000  0.370429  0.251662  ...               0.592211
# 478  0.189306  0.225581  0.206593  ...               0.492107
# 479  0.240751  0.445890  0.305984  ...               0.633193
#
#      WORD_PROPERTY_WRDHYPv  WORD_PROPERTY_WRDHYPnv  WORD_PROPERTY_AOA  \
# 0                 0.233333                0.363359           0.536598
# 1                 0.278947                0.072002           0.057090
# 2                 0.150980                0.439013           0.197521
# 3                 0.146154                0.479820           0.101196
# 4                 0.313333                0.399818           0.219840
# ..                     ...                     ...                ...
# 475               0.452381                0.532710           0.293080
# 476               0.119608                0.261489           0.097540
# 477               0.322222                0.538168           0.352350
# 478               0.056863                0.330483           0.095886
# 479               0.255556                0.476738           0.629851
#
#      WORD_PROPERTY_AOA_MAX  WORD_PROPERTY_CONCRETENESS  \
# 0                 0.396186                    0.393986
# 1                 0.309322                    0.612986
# 2                 0.297608                    0.685996
# 3                 0.147246                    0.814876
# 4                 0.617585                    0.218604
# ..                     ...                         ...
# 475               0.306847                    0.621988
# 476               0.323093                    0.499129
# 477               0.606992                    0.835890
# 478               0.423729                    0.532790
# 479               0.447034                    0.534365
#
#      WORD_PROPERTY_PREVALENCE  WORD_PROPERTY_PREVALENCE_MIN  \
# 0                    0.674648                      0.674648
# 1                    0.682585                      0.682585
# 2                    0.654967                      0.654967
# 3                    0.426085                      0.426085
# 4                    0.515320                      0.515320
# ..                        ...                           ...
# 475                  0.530017                      0.530017
# 476                  0.691053                      0.691053
# 477                  0.640981                      0.640981
# 478                  0.651265                      0.651265
# 479                  0.574802                      0.574802
#
#      WORD_SET_INCIDENCE_C4_COMMON_WORDS  Polarity
# 0                              0.685198      Fake
# 1                              0.252618      Fake
# 2                              0.546360      Fake
# 3                              0.367094      Fake
# 4                              0.550734      Fake
# ..                                  ...       ...
# 475                            0.516772      True
# 476                            0.339440      True
# 477                            0.230619      True
# 478                            0.156495      True
# 479                            0.268774      True
#
# [480 rows x 63 columns]

# %%
#Dropping the features that have NaN values

nan_dict = {}
for col in all_fts:
    nan_dict[col] = all_fts[col].isna().sum()
print(nan_dict)

for k in nan_dict:
    if nan_dict[k] > 0:
        all_fts = all_fts.drop(labels=k, axis = 1)

data = all_fts
# Out:
# {'DESPC': 0, 'DESSC': 0, 'DESWC': 0, 'DESPL': 0, 'DESPLd': 30, 'DESPLw': 0, 'DESSL': 0, 'DESSLd': 0, 'DESWLsy': 0, 'DESWLsyd': 0, 'DESWLlt': 0, 'DESWLltd': 0, 'LDTTRc': 0, 'LDTTRa': 0, 'LDMTLD': 0, 'LDHDD': 0, 'SYNLE': 0, 'SYNNP': 0, 'SYNMEDpos': 0, 'SYNMEDwrd': 0, 'SYNMEDlem': 0, 'SYNSTRUTa': 0, 'SYNSTRUTt': 480, 'RDFRE': 0, 'READFKGL': 0, 'TOKEN_ATTRIBUTE_RATIO_ALHPA': 0, 'TOKEN_ATTRIBUTE_RATIO_DIGIT': 0, 'TOKEN_ATTRIBUTE_RATIO_PUNCT': 0, 'TOKEN_ATTRIBUTE_RATIO_URL': 0, 'TOKEN_ATTRIBUTE_RATIO_EMAIL': 480, 'WORD_SET_INCIDENCE_WRDPRP1s': 0, 'WORD_SET_INCIDENCE_WRDPRP1p': 0, 'WORD_SET_INCIDENCE_WRDPRP2': 0, 'WORD_SET_INCIDENCE_WRDPRP3s': 0, 'WORD_SET_INCIDENCE_WRDPRP3p': 0, 'WORD_SET_INCIDENCE_CNCCaus': 0, 'WORD_SET_INCIDENCE_CNCLogic': 0, 'WORD_SET_INCIDENCE_CNCTemp': 0, 'WORD_SET_INCIDENCE_CNCAdd': 0, 'WORD_SET_INCIDENCE_CNCPos': 0, 'WORD_SET_INCIDENCE_CNCNeg': 0, 'WORD_PROPERTY_WRDNOUN': 0, 'WORD_PROPERTY_WRDVERB': 0, 'WORD_PROPERTY_WRDADJ': 0, 'WORD_PROPERTY_WRDADV': 0, 'WORD_PROPERTY_WRDFRQc': 0, 'WORD_PROPERTY_WRDFRQa': 0, 'WORD_PROPERTY_WRDFRQmc': 0, 'WORD_PROPERTY_WRDFAMc': 0, 'WORD_PROPERTY_WRDCNCc': 0, 'WORD_PROPERTY_WRDIMGc': 0, 'WORD_PROPERTY_WRDMEAc': 0, 'WORD_PROPERTY_WRDPOLc': 0, 'WORD_PROPERTY_WRDHYPn': 0, 'WORD_PROPERTY_WRDHYPv': 0, 'WORD_PROPERTY_WRDHYPnv': 0, 'WORD_PROPERTY_AOA': 0, 'WORD_PROPERTY_AOA_MAX': 0, 'WORD_PROPERTY_CONCRETENESS': 0, 'WORD_PROPERTY_PREVALENCE': 0, 'WORD_PROPERTY_PREVALENCE_MIN': 0, 'WORD_SET_INCIDENCE_C4_COMMON_WORDS': 0, 'Polarity': 0}

# %%
features = list(all_fts.columns)[:-1]
print(features)
# Out:
# ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS']

# %%
models = [LogisticRegression(), SVC(kernel ="linear"), KNeighborsClassifier(), RandomForestClassifier()]

# %%
models_all_available_features = magic(data, features)
# Out:
# Info: 59 features were passed at the fit step
# :
# DESPC
# DESSC
# DESWC
# DESPL
# DESPLw
# DESSL
# DESSLd
# DESWLsy
# DESWLsyd
# DESWLlt
# DESWLltd
# LDTTRc
# LDTTRa
# LDMTLD
# LDHDD
# SYNLE
# SYNNP
# SYNMEDpos
# SYNMEDwrd
# SYNMEDlem
# SYNSTRUTa
# RDFRE
# READFKGL
# TOKEN_ATTRIBUTE_RATIO_ALHPA
# TOKEN_ATTRIBUTE_RATIO_DIGIT
# TOKEN_ATTRIBUTE_RATIO_PUNCT
# TOKEN_ATTRIBUTE_RATIO_URL
# WORD_SET_INCIDENCE_WRDPRP1s
# WORD_SET_INCIDENCE_WRDPRP1p
# WORD_SET_INCIDENCE_WRDPRP2
# WORD_SET_INCIDENCE_WRDPRP3s
# WORD_SET_INCIDENCE_WRDPRP3p
# WORD_SET_INCIDENCE_CNCCaus
# WORD_SET_INCIDENCE_CNCLogic
# WORD_SET_INCIDENCE_CNCTemp
# WORD_SET_INCIDENCE_CNCAdd
# WORD_SET_INCIDENCE_CNCPos
# WORD_SET_INCIDENCE_CNCNeg
# WORD_PROPERTY_WRDNOUN
# WORD_PROPERTY_WRDVERB
# WORD_PROPERTY_WRDADJ
# WORD_PROPERTY_WRDADV
# WORD_PROPERTY_WRDFRQc
# WORD_PROPERTY_WRDFRQa
# WORD_PROPERTY_WRDFRQmc
# WORD_PROPERTY_WRDFAMc
# WORD_PROPERTY_WRDCNCc
# WORD_PROPERTY_WRDIMGc
# WORD_PROPERTY_WRDMEAc
# WORD_PROPERTY_WRDPOLc
# WORD_PROPERTY_WRDHYPn
# WORD_PROPERTY_WRDHYPv
# WORD_PROPERTY_WRDHYPnv
# WORD_PROPERTY_AOA
# WORD_PROPERTY_AOA_MAX
# WORD_PROPERTY_CONCRETENESS
# WORD_PROPERTY_PREVALENCE
# WORD_PROPERTY_PREVALENCE_MIN
# WORD_SET_INCIDENCE_C4_COMMON_WORDS
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 81.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.82      0.82      0.82        60
#         Real       0.82      0.82      0.82        60
#
#     accuracy                           0.82       120
#    macro avg       0.82      0.82      0.82       120
# weighted avg       0.82      0.82      0.82       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 85.42 %
# 80.21 %
# 81.25 %
# 85.42 %
# 78.12 %
#
# Cross validation mean accuracy for LogisticRegression: 82.08 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 85.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.86      0.85      0.86        60
#         Real       0.85      0.87      0.86        60
#
#     accuracy                           0.86       120
#    macro avg       0.86      0.86      0.86       120
# weighted avg       0.86      0.86      0.86       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 87.5 %
# 81.25 %
# 81.25 %
# 88.54 %
# 81.25 %
#
# Cross validation mean accuracy for SVC: 83.96 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 68.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.75      0.55      0.63        60
#         Real       0.64      0.82      0.72        60
#
#     accuracy                           0.68       120
#    macro avg       0.70      0.68      0.68       120
# weighted avg       0.70      0.68      0.68       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 72.92 %
# 69.79 %
# 71.88 %
# 71.88 %
# 69.79 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 71.25 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 87.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.84      0.93      0.88        60
#         Real       0.92      0.82      0.87        60
#
#     accuracy                           0.88       120
#    macro avg       0.88      0.88      0.87       120
# weighted avg       0.88      0.88      0.87       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 86.46 %
# 77.08 %
# 85.42 %
# 81.25 %
# 83.33 %
#
# Cross validation mean accuracy for RandomForestClassifier: 82.71 %
#
# -------------------------------------------------------------------------

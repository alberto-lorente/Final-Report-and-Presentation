# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\Dummy DATASET to test\Raw 2nd DATASET\fake_or_real_news.csv", engine="python")

# %%
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data.shape
# Out:
# (6335, 4)

# %%
data.label[data.label == 'FAKE'] = 0
data.label[data.label == 'REAL'] = 1
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_14412\1349018505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.label[data.label == 'FAKE'] = 0
# C:\Users\alber\AppData\Local\Temp\ipykernel_14412\1349018505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.label[data.label == 'REAL'] = 1

# %%
for row in data.title:
  if not row.endswith(". "):
    row = row + ". "
  print(row)
# Out:
# You Can Smell Hillary’s Fear.
# Watch The Exact Moment Paul Ryan Committed Political Suicide At A Trump Rally (VIDEO).
# Kerry to go to Paris in gesture of sympathy.
# Bernie supporters on Twitter erupt in anger against the DNC: 'We tried to warn you!'.
# The Battle of New York: Why This Primary Matters.
# Tehran, USA.
# Girl Horrified At What She Watches Boyfriend Do After He Left FaceTime On.
# ‘Britain’s Schindler’ Dies at 106.
# Fact check: Trump and Clinton at the 'commander-in-chief' forum.
# Iran reportedly makes new push for uranium concessions in nuclear talks.
# With all three Clintons in Iowa, a glimpse at the fire that has eluded Hillary Clinton’s campaign.
# Donald Trump’s Shockingly Weak Delegate Game Somehow Got Even Worse.
# Strong Solar Storm, Tech Risks Today | S0 News Oct.26.2016 [VIDEO].
# 10 Ways America Is Preparing for World War 3.
# Trump takes on Cruz, but lightly.
# How women lead differently.
# ...

# %%
data.text = data.title + data.text

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label'], dtype='object')

# %%
data = data.drop(labels="title", axis=1)

# %%
data.rename(columns={"Unnamed: 0":"id"}, inplace=True)
data
# Out:
#          id                                               text label
# 0      8476  You Can Smell Hillary’s FearDaniel Greenfield,...     0
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...     0
# 2      3608  Kerry to go to Paris in gesture of sympathyU.S...     1
# 3     10142  Bernie supporters on Twitter erupt in anger ag...     0
# 4       875  The Battle of New York: Why This Primary Matte...     1
# ...     ...                                                ...   ...
# 6330   4490  State Department says it can't find emails fro...     1
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...     0
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...     0
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...     1
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...     1
#
# [6335 rows x 3 columns]

# %%
data.id.duplicated().unique()
# Out:
# array([False])

# %%
data.rename(columns={"label":"Polarity"}, inplace=True)
fake_test = data[data.Polarity == 0]
true_test = data[data.Polarity == 1]

# %%
fake_test
# Out:
#          id                                               text Polarity
# 0      8476  You Can Smell Hillary’s FearDaniel Greenfield,...        0
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...        0
# 3     10142  Bernie supporters on Twitter erupt in anger ag...        0
# 5      6903  Tehran, USA  \r\nI’m not an immigrant, but my ...        0
# 6      7341  Girl Horrified At What She Watches Boyfriend D...        0
# ...     ...                                                ...      ...
# 6326   6143  DOJ COMPLAINT: Comey Under Fire Over Partisan ...        0
# 6328   9337  Radio Derb Is On The Air–Leonardo And Brazil’s...        0
# 6329   8737  Assange claims ‘crazed’ Clinton campaign tried...        0
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...        0
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...        0
#
# [3164 rows x 3 columns]

# %%
true_test
# Out:
#         id                                               text Polarity
# 2     3608  Kerry to go to Paris in gesture of sympathyU.S...        1
# 4      875  The Battle of New York: Why This Primary Matte...        1
# 7       95  ‘Britain’s Schindler’ Dies at 106A Czech stock...        1
# 8     4869  Fact check: Trump and Clinton at the 'commande...        1
# 9     2909  Iran reportedly makes new push for uranium con...        1
# ...    ...                                                ...      ...
# 6324  2316  Alabama Lawmaker: Same-Sex Couples Don’t Deser...        1
# 6327  3262  GOP Senator David Perdue Jokes About Praying f...        1
# 6330  4490  State Department says it can't find emails fro...        1
# 6333  4021  In Ethiopia, Obama seeks progress on peace, se...        1
# 6334  4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...        1
#
# [3171 rows x 3 columns]

# %%
fake_test.to_csv(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\fake_test')

# %%
true_test.to_csv(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\true_test')

# %%
real_data_pre = pd.read_table(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\data_2_processed.tsv', delimiter = '\t')

fake_data_pre = pd.read_table(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\data_2_processed.tsv', delimiter = '\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 real_data_pre = pd.read_table(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\data_2_processed.tsv', delimiter = '\t')
#       3 fake_data_pre = pd.read_table(r'C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\data_2_processed.tsv', delimiter = '\t')
#
# ...

# %%
# more preprocessing

data_pre.pop("text_key")
data_max_scaled = pd.DataFrame()
for column in data_pre.columns:
  data_max_scaled[column]=(data_pre[column]-data_pre[column].min())/(data_pre[column].max()-data_pre[column].min())

# %%
data_pre.to_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\data_pre_tp_test.csv")

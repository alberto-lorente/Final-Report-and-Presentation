# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support

import os
import pickle

import json

# %%
from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %%
def get_feature_list(model):
    
    '''This function looks for the dictionary associated with a model 
    to get the features we used during the fit automatically as a list
    '''
       
    models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\MODELS"
    dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\DICTS"

    list_models = os.listdir(models_path)
    list_dicts = os.listdir(dict_path)
    
    # print(len(list_models), list_models)
    # print(len(list_dicts),list_dicts)
    
       
    for i in range(len(list_dicts)):

        model_name = str(model).split(".")[0]
        name_dict = str(list_dicts[i]).split(".")[0]
        
        if model_name == name_dict:
            
            dict_path = str(dict_path)+ r"\{}".format(str(list_dicts[i]))
            
            with open(dict_path) as f:
                data = json.load(f)
            
            model_name = data["name"]
            features = data["features"]
            model_type = data["model"]
        # print(features)
        
        model_path = str(models_path) + r"\{}".format(model)
        
    return features, model_name, model_type, model_path



def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def data_cleaning(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y_test = data["Polarity"] #outcomes 0 or 1


  # print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  # for feature in feature_cols:
  #   print(feature)

  return X, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores


def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  plt.title("{} Confusion Matrix: ".format(model_name), y = 1.1)



  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(model, model_type, model_name, X, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''
    
    
    
  model_dict = {}

  model_dict["name"] = model_name

  model_dict["features"] = features

  model_dict["model"] = model_type

  print("\n",model_name, "\n", "\n")

  y_pred = model.predict(X)

  accuracy = accuracy_score(y_test, y_pred)

  model_dict["accuracy"] = accuracy

  print("OVERALL ACCURACY", model_dict["name"], ":", round(accuracy*100, 2),"%""\n")

  scores = class_report(y_test, y_pred)

  P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
  precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]

  P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
  precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]

  model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
  model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

  confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")

  model_dict["confussion_matrix"] = confussion_matrix
  
  model_dict["data_test_source"] = "second dataset"
  
  model_dict["training_normalized_together"] = "yes"

  model_dict["testing_normalized_together"] = "yes"

  with open(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Testing\Testing normalized together\With normalized trainng\{}_TEST.json".format(model_dict["name"]), "w") as f:
    json.dump(model_dict, f, cls=NumpyArrayEncoder)
    
    
  return model_dict

# %%
def magic_eva(data, model):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''
  
  features, model_name, model_type, model_path = get_feature_list(model)

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y_test, features = data_cleaning(data, features) # data split for all the models with the desired features
  
  model = pickle.load(open (model_path, "rb"))

  model_dict = compare_models_train_test_split(model, model_type, model_name, X, y_test, features) # for each model it will compute

  return model_dict

# %%
data = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\test_data_normalized_together.csv")

# %%
models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\MODELS"
dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\DICTS"

list_models = os.listdir(models_path)
list_dicts = os.listdir(dict_path)

list_dicts_performance = []

for model in list_models:
    dict_model = magic_eva(data, model)
    
    list_dicts_performance.append(dict_model)
    # print(dict_model)
# Out:
#  All_features__KNeighborsClassifier
#
#
# OVERALL ACCURACY All_features__KNeighborsClassifier : 44.35 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.44      0.35      0.39      3079
#         Real       0.44      0.54      0.49      2968
#
#     accuracy                           0.44      6047
#    macro avg       0.44      0.45      0.44      6047
# weighted avg       0.44      0.44      0.44      6047
#
#
#  All_features__LogisticRegression
#
#
# OVERALL ACCURACY All_features__LogisticRegression : 57.32 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.55      0.90      0.68      3079
#         Real       0.69      0.23      0.35      2968
#
#     accuracy                           0.57      6047
#    macro avg       0.62      0.57      0.52      6047
# weighted avg       0.62      0.57      0.52      6047
#
#
#  All_features__RandomForestClassifier
#
#
# OVERALL ACCURACY All_features__RandomForestClassifier : 55.91 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.32      0.43      3079
#         Real       0.53      0.80      0.64      2968
#
#     accuracy                           0.56      6047
#    macro avg       0.58      0.56      0.53      6047
# weighted avg       0.58      0.56      0.53      6047
#
#
#  All_features__SVC
#
#
# OVERALL ACCURACY All_features__SVC : 62.28 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.60      0.80      0.68      3079
#         Real       0.68      0.44      0.53      2968
#
#     accuracy                           0.62      6047
#    macro avg       0.64      0.62      0.61      6047
# weighted avg       0.64      0.62      0.61      6047
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 42.47 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.44      0.76      0.55      2613
#         Real       0.37      0.13      0.19      2913
#
#     accuracy                           0.42      5526
#    macro avg       0.40      0.44      0.37      5526
# weighted avg       0.40      0.42      0.36      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 53.55 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.80      0.02      0.05      2613
#         Real       0.53      0.99      0.69      2913
#
#     accuracy                           0.54      5526
#    macro avg       0.67      0.51      0.37      5526
# weighted avg       0.66      0.54      0.39      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 50.25 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.47      0.44      0.46      2613
#         Real       0.53      0.56      0.54      2913
#
#     accuracy                           0.50      5526
#    macro avg       0.50      0.50      0.50      5526
# weighted avg       0.50      0.50      0.50      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 52.9 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.00      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 53.84 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.06      0.10      2613
#         Real       0.53      0.97      0.69      2913
#
#     accuracy                           0.54      5526
#    macro avg       0.59      0.51      0.40      5526
# weighted avg       0.58      0.54      0.41      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 53.15 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.36      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 46.6 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.47      0.89      0.61      2613
#         Real       0.46      0.08      0.14      2913
#
#     accuracy                           0.47      5526
#    macro avg       0.46      0.49      0.38      5526
# weighted avg       0.46      0.47      0.36      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__SVC : 52.8 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.00      0.00      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__KNeighborsClassifier : 53.66 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.05      0.09      2613
#         Real       0.53      0.98      0.69      2913
#
#     accuracy                           0.54      5526
#    macro avg       0.58      0.51      0.39      5526
# weighted avg       0.58      0.54      0.40      5526
#
#
#  DESWLltd__DESPLd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__LogisticRegression : 53.2 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.01      0.02      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.51      0.36      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__RandomForestClassifier : 54.09 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.68      0.06      0.10      2613
#         Real       0.54      0.98      0.69      2913
#
#     accuracy                           0.54      5526
#    macro avg       0.61      0.52      0.40      5526
# weighted avg       0.60      0.54      0.41      5526
#
#
#  DESWLltd__DESPLd__SVC
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__SVC : 52.84 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.00      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.76      0.50      0.35      5526
# weighted avg       0.75      0.53      0.37      5526
#
#
#  DESWLltd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__KNeighborsClassifier : 47.31 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.48      0.83      0.61      3159
#         Real       0.41      0.12      0.19      3171
#
#     accuracy                           0.47      6330
#    macro avg       0.45      0.47      0.40      6330
# weighted avg       0.45      0.47      0.40      6330
#
#
#  DESWLltd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__LogisticRegression : 49.18 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.99      0.66      3159
#         Real       0.00      0.00      0.00      3171
#
#     accuracy                           0.49      6330
#    macro avg       0.25      0.49      0.33      6330
# weighted avg       0.25      0.49      0.33      6330
#
#
#  DESWLltd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__RandomForestClassifier : 47.76 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.48      0.74      0.58      3159
#         Real       0.46      0.22      0.30      3171
#
#     accuracy                           0.48      6330
#    macro avg       0.47      0.48      0.44      6330
# weighted avg       0.47      0.48      0.44      6330
#
#
#  DESWLltd__SVC
#
#
# OVERALL ACCURACY DESWLltd__SVC : 49.73 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      1.00      0.66      3159
#         Real       0.00      0.00      0.00      3171
#
#     accuracy                           0.50      6330
#    macro avg       0.25      0.50      0.33      6330
# weighted avg       0.25      0.50      0.33      6330
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 48.52 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.49      0.96      0.65      3134
#         Real       0.27      0.01      0.03      3170
#
#     accuracy                           0.49      6304
#    macro avg       0.38      0.49      0.34      6304
# weighted avg       0.38      0.49      0.34      6304
# C:\Users\alber\AppData\Local\Temp\ipykernel_16096\805683876.py:97: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
#  DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 49.37 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.99      0.66      3134
#         Real       0.00      0.00      0.00      3170
#
#     accuracy                           0.49      6304
#    macro avg       0.25      0.50      0.33      6304
# weighted avg       0.25      0.49      0.33      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 48.13 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.49      0.96      0.65      3134
#         Real       0.09      0.00      0.01      3170
#
#     accuracy                           0.48      6304
#    macro avg       0.29      0.48      0.33      6304
# weighted avg       0.29      0.48      0.33      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 49.46 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.99      0.66      3134
#         Real       0.00      0.00      0.00      3170
#
#     accuracy                           0.49      6304
#    macro avg       0.25      0.50      0.33      6304
# weighted avg       0.25      0.49      0.33      6304

# %%
print(len(list_dicts_performance))
print(list_dicts_performance)
# Out:
# 24
# [{'name': 'All_features__KNeighborsClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'KNeighborsClassifier', 'accuracy': 0.4435257152306929, 'precision_true': array([0.44496812]), 'recall_true': array([0.54076819]), 'f1_score_true': array([0.48821293]), 'precision_false': array([0.44139344]), 'recall_false': array([0.34978889]), 'f1_score_false': array([0.3902881]), 'confussion_matrix': array([[1077, 1363],
#        [2002, 1605]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'All_features__LogisticRegression', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'LogisticRegression', 'accuracy': 0.5731767818753101, 'precision_true': array([0.69408225]), 'recall_true': array([0.23315364]), 'f1_score_true': array([0.34905422]), 'precision_false': array([0.54930693]), 'recall_false': array([0.90094186]), 'f1_score_false': array([0.68249477]), 'confussion_matrix': array([[2774, 2276],
#        [ 305,  692]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'All_features__RandomForestClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'RandomForestClassifier', 'accuracy': 0.5591202249049115, 'precision_true': array([0.53375056]), 'recall_true': array([0.80458221]), 'f1_score_true': array([0.64176297]), 'precision_false': array([0.63127781]), 'recall_false': array([0.32250731]), 'f1_score_false': array([0.42691316]), 'confussion_matrix': array([[ 993,  580],
#        [2086, 2388]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'All_features__SVC', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'SVC', 'accuracy': 0.6227881594178931, 'precision_true': array([0.67825636]), 'recall_true': array([0.44036388]), 'f1_score_true': array([0.5340143]), 'precision_false': array([0.59684466]), 'recall_false': array([0.79863592]), 'f1_score_false': array([0.68315044]), 'confussion_matrix': array([[2459, 1661],
#        [ 620, 1307]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.42471950778139705, 'precision_true': array([0.36805556]), 'recall_true': array([0.12736011]), 'f1_score_true': array([0.18923744]), 'precision_false': array([0.43736166]), 'recall_false': array([0.75621891]), 'f1_score_false': array([0.55419997]), 'confussion_matrix': array([[1976, 2542],
#        [ 637,  371]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5354686934491495, 'precision_true': array([0.53174312]), 'recall_true': array([0.99485067]), 'f1_score_true': array([0.69305273]), 'precision_false': array([0.80263158]), 'recall_false': array([0.02334481]), 'f1_score_false': array([0.04537003]), 'confussion_matrix': array([[  61,   15],
#        [2552, 2898]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.5025334781035107, 'precision_true': array([0.52652005]), 'recall_true': array([0.55887401]), 'f1_score_true': array([0.54221482]), 'precision_false': array([0.47206245]), 'recall_false': array([0.43972445]), 'f1_score_false': array([0.45531999]), 'confussion_matrix': array([[1149, 1285],
#        [1464, 1628]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5289540354686935, 'precision_true': array([0.52810007]), 'recall_true': array([1.]), 'f1_score_true': array([0.69118519]), 'precision_false': array([1.]), 'recall_false': array([0.00382702]), 'f1_score_false': array([0.00762486]), 'confussion_matrix': array([[  10,    0],
#        [2603, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5383640969960188, 'precision_true': array([0.53416384]), 'recall_true': array([0.97150704]), 'f1_score_true': array([0.68931921]), 'precision_false': array([0.63596491]), 'recall_false': array([0.05549177]), 'f1_score_false': array([0.10207673]), 'confussion_matrix': array([[ 145,   83],
#        [2468, 2830]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5314875135722041, 'precision_true': array([0.52944384]), 'recall_true': array([1.]), 'f1_score_true': array([0.69233512]), 'precision_false': array([1.]), 'recall_false': array([0.00918485]), 'f1_score_false': array([0.0182025]), 'confussion_matrix': array([[  24,    0],
#        [2589, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.4659790083242852, 'precision_true': array([0.46289062]), 'recall_true': array([0.08135942]), 'f1_score_true': array([0.13839416]), 'precision_false': array([0.46629438]), 'recall_false': array([0.89475698]), 'f1_score_false': array([0.61308509]), 'confussion_matrix': array([[2338, 2676],
#        [ 275,  237]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5280492218602968, 'precision_true': array([0.52762181]), 'recall_true': array([1.]), 'f1_score_true': array([0.69077543]), 'precision_false': array([1.]), 'recall_false': array([0.00191351]), 'f1_score_false': array([0.00381971]), 'confussion_matrix': array([[   5,    0],
#        [2608, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__KNeighborsClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5365544697792255, 'precision_true': array([0.53299588]), 'recall_true': array([0.97596979]), 'f1_score_true': array([0.68946283]), 'precision_false': array([0.63541667]), 'recall_false': array([0.04668963]), 'f1_score_false': array([0.08698752]), 'confussion_matrix': array([[ 122,   70],
#        [2491, 2843]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__LogisticRegression', 'features': ['DESWLltd', 'DESPLd'], 'model': 'LogisticRegression', 'accuracy': 0.5320304017372421, 'precision_true': array([0.52973268]), 'recall_true': array([1.]), 'f1_score_true': array([0.69258203]), 'precision_false': array([1.]), 'recall_false': array([0.01033295]), 'f1_score_false': array([0.02045455]), 'confussion_matrix': array([[  27,    0],
#        [2586, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__RandomForestClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'RandomForestClassifier', 'accuracy': 0.5408975750995295, 'precision_true': array([0.53539157]), 'recall_true': array([0.97631308]), 'f1_score_true': array([0.69155015]), 'precision_false': array([0.67757009]), 'recall_false': array([0.05549177]), 'f1_score_false': array([0.10258224]), 'confussion_matrix': array([[ 145,   69],
#        [2468, 2844]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__DESPLd__SVC', 'features': ['DESWLltd', 'DESPLd'], 'model': 'SVC', 'accuracy': 0.5284111473036555, 'precision_true': array([0.52781301]), 'recall_true': array([1.]), 'f1_score_true': array([0.69093928]), 'precision_false': array([1.]), 'recall_false': array([0.00267891]), 'f1_score_false': array([0.00534351]), 'confussion_matrix': array([[   7,    0],
#        [2606, 2913]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__KNeighborsClassifier', 'features': ['DESWLltd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.4731437598736177, 'precision_true': array([0.41257996]), 'recall_true': array([0.12204352]), 'f1_score_true': array([0.188367]), 'precision_false': array([0.48367953]), 'recall_false': array([0.82557771]), 'f1_score_false': array([0.60998714]), 'confussion_matrix': array([[2608, 2784],
#        [ 551,  387]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__LogisticRegression', 'features': ['DESWLltd'], 'model': 'LogisticRegression', 'accuracy': 0.49178515007898893, 'precision_true': array([0.]), 'recall_true': array([0.]), 'f1_score_true': array([0.]), 'precision_false': array([0.49538511]), 'recall_false': array([0.98543843]), 'f1_score_false': array([0.65932437]), 'confussion_matrix': array([[3113, 3171],
#        [  46,    0]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__RandomForestClassifier', 'features': ['DESWLltd'], 'model': 'RandomForestClassifier', 'accuracy': 0.47756714060031596, 'precision_true': array([0.45538058]), 'recall_true': array([0.2188584]), 'f1_score_true': array([0.29563365]), 'precision_false': array([0.48460258]), 'recall_false': array([0.73725863]), 'f1_score_false': array([0.58480854]), 'confussion_matrix': array([[2329, 2477],
#        [ 830,  694]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__SVC', 'features': ['DESWLltd'], 'model': 'SVC', 'accuracy': 0.4973143759873618, 'precision_true': array([0.]), 'recall_true': array([0.]), 'f1_score_true': array([0.]), 'precision_false': array([0.49818009]), 'recall_false': array([0.99651789]), 'f1_score_false': array([0.66427516]), 'confussion_matrix': array([[3148, 3171],
#        [  11,    0]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.48524746192893403, 'precision_true': array([0.26993865]), 'recall_true': array([0.01388013]), 'f1_score_true': array([0.02640264]), 'precision_false': array([0.49096238]), 'recall_false': array([0.96202936]), 'f1_score_false': array([0.65013477]), 'confussion_matrix': array([[3015, 3126],
#        [ 119,   44]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.4936548223350254, 'precision_true': array([0.]), 'recall_true': array([0.]), 'f1_score_true': array([0.]), 'precision_false': array([0.49538364]), 'recall_false': array([0.99298022]), 'f1_score_false': array([0.66100255]), 'confussion_matrix': array([[3112, 3170],
#        [  22,    0]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.48128172588832485, 'precision_true': array([0.09016393]), 'recall_true': array([0.00347003]), 'f1_score_true': array([0.00668287]), 'precision_false': array([0.48900032]), 'recall_false': array([0.964582]), 'f1_score_false': array([0.64899098]), 'confussion_matrix': array([[3023, 3159],
#        [ 111,   11]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.49460659898477155, 'precision_true': array([0.]), 'recall_true': array([0.]), 'f1_score_true': array([0.]), 'precision_false': array([0.49586514]), 'recall_false': array([0.9948947]), 'f1_score_false': array([0.66185523]), 'confussion_matrix': array([[3118, 3170],
#        [  16,    0]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'yes'}]

# %% [markdown]
# do a mirror pair of models trained with this data and tested in the second dataset/fine tune

# %% [markdown]
# '''
#
# small crossvalidation to make sure model is stableand std bt the scores , lucky distr.
#
# data augmentation - + at the end with the generation model, feed the model with new elements
#
# method to input some text and see the prediction irt,
# automatically add fake news text to the data
#
#
# this is quant but we need qualitative
#
# SMOTE libary for DAug
#
# name of the file and template of the acl file - subsections things
#
# qualitative vs quantitative studies
#
# '''

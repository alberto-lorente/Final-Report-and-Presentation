# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support

import os
import pickle

import json

# %%
from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %%
def get_feature_list(model):
    
    '''This function looks for the dictionary associated with a model 
    to get the features we used during the fit automatically as a list
    '''
       
    models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Models"
    dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Dicts"

    list_models = os.listdir(models_path)
    list_dicts = os.listdir(dict_path)
    
    # print(len(list_models), list_models)
    # print(len(list_dicts),list_dicts)
    
       
    for i in range(len(list_dicts)):

        model_name = str(model).split(".")[0]
        name_dict = str(list_dicts[i]).split(".")[0]
        
        if model_name == name_dict:
            
            dict_path = str(dict_path)+ r"\{}".format(str(list_dicts[i]))
            
            with open(dict_path) as f:
                data = json.load(f)
            
            model_name = data["name"]
            features = data["features"]
            model_type = data["model"]
        # print(features)
        
        model_path = str(models_path) + r"\{}".format(model)
        
    return features, model_name, model_type, model_path



def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def data_cleaning(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y_test = data["Polarity"] #outcomes 0 or 1


  # print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  # for feature in feature_cols:
  #   print(feature)

  return X, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores


def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  plt.title("{} Confusion Matrix: ".format(model_name), y = 1.1)



  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(model, model_type, model_name, X, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''
    
    
    
  model_dict = {}

  model_dict["name"] = model_name

  model_dict["features"] = features

  model_dict["model"] = model_type

  print("\n",model_name, "\n", "\n")

  y_pred = model.predict(X)

  accuracy = accuracy_score(y_test, y_pred)

  model_dict["accuracy"] = accuracy

  print("OVERALL ACCURACY", model_dict["name"], ":", round(accuracy*100, 2),"%""\n")

  scores = class_report(y_test, y_pred)

  P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
  precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]

  P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
  precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]

  model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
  model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

  confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")

  model_dict["confussion_matrix"] = confussion_matrix
  
  model_dict["data_test_source"] = "second dataset"
  
  model_dict["training_normalized_together"] = "yes"

  model_dict["testing_normalized_together"] = "no"

  with open(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Dicts training normalized together, test normalized separately\{}_TEST.json".format(model_dict["name"]), "w") as f:
    json.dump(model_dict, f, cls=NumpyArrayEncoder)
    
    
  return model_dict

# %%
def magic_eva(data, model):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''
  
  features, model_name, model_type, model_path = get_feature_list(model)

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y_test, features = data_cleaning(data, features) # data split for all the models with the desired features
  
  model = pickle.load(open (model_path, "rb"))

  model_dict = compare_models_train_test_split(model, model_type, model_name, X, y_test, features) # for each model it will compute

  return model_dict

# %%
data = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\Data\Model Testing\test_data")

# %%
models_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Models"
dict_path = r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Dicts"

list_models = os.listdir(models_path)
list_dicts = os.listdir(dict_path)

list_dicts_performance = []

for model in list_models:
    dict_model = magic_eva(data, model)
    
    list_dicts_performance.append(dict_model)
    # print(dict_model)
# Out:
#  All_features__KNeighborsClassifier
#
#
# OVERALL ACCURACY All_features__KNeighborsClassifier : 52.92 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.60      0.24      0.34      3079
#         Real       0.51      0.83      0.63      2968
#
#     accuracy                           0.53      6047
#    macro avg       0.55      0.53      0.49      6047
# weighted avg       0.55      0.53      0.48      6047
#
#
#  All_features__LogisticRegression
#
#
# OVERALL ACCURACY All_features__LogisticRegression : 56.42 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.54      0.91      0.68      3079
#         Real       0.68      0.21      0.32      2968
#
#     accuracy                           0.56      6047
#    macro avg       0.61      0.56      0.50      6047
# weighted avg       0.61      0.56      0.50      6047
#
#
#  All_features__RandomForestClassifier
#
#
# OVERALL ACCURACY All_features__RandomForestClassifier : 47.73 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.44      0.09      0.15      3079
#         Real       0.48      0.88      0.62      2968
#
#     accuracy                           0.48      6047
#    macro avg       0.46      0.48      0.39      6047
# weighted avg       0.46      0.48      0.38      6047
#
#
#  All_features__SVC
#
#
# OVERALL ACCURACY All_features__SVC : 49.48 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.81      0.62      3079
#         Real       0.46      0.17      0.24      2968
#
#     accuracy                           0.49      6047
#    macro avg       0.48      0.49      0.43      6047
# weighted avg       0.48      0.49      0.44      6047
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 85.78 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.93      0.76      0.83      2613
#         Real       0.81      0.95      0.88      2913
#
#     accuracy                           0.86      5526
#    macro avg       0.87      0.85      0.85      5526
# weighted avg       0.87      0.86      0.86      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 53.35 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.70      0.02      0.05      2613
#         Real       0.53      0.99      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.62      0.51      0.37      5526
# weighted avg       0.61      0.53      0.39      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 50.54 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.42      0.13      0.19      2613
#         Real       0.52      0.85      0.64      2913
#
#     accuracy                           0.51      5526
#    macro avg       0.47      0.49      0.42      5526
# weighted avg       0.47      0.51      0.43      5526
#
#
#  DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 52.53 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.33      0.00      0.01      2613
#         Real       0.53      0.99      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.43      0.50      0.35      5526
# weighted avg       0.44      0.53      0.37      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 49.02 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.29      0.06      0.09      2613
#         Real       0.51      0.88      0.65      2913
#
#     accuracy                           0.49      5526
#    macro avg       0.40      0.47      0.37      5526
# weighted avg       0.41      0.49      0.38      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 51.39 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.20      0.01      0.02      2613
#         Real       0.52      0.97      0.68      2913
#
#     accuracy                           0.51      5526
#    macro avg       0.36      0.49      0.35      5526
# weighted avg       0.37      0.51      0.37      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 88.6 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.88      0.88      0.88      2613
#         Real       0.89      0.89      0.89      2913
#
#     accuracy                           0.89      5526
#    macro avg       0.89      0.89      0.89      5526
# weighted avg       0.89      0.89      0.89      5526
#
#
#  DESPLd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESPLd__WORD_PROPERTY_WRDHYPn__SVC : 52.46 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.21      0.00      0.00      2613
#         Real       0.53      0.99      0.69      2913
#
#     accuracy                           0.52      5526
#    macro avg       0.37      0.50      0.35      5526
# weighted avg       0.38      0.52      0.36      5526
#
#
#  DESWLltd__DESPLd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__KNeighborsClassifier : 52.73 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.05      0.09      2613
#         Real       0.53      0.96      0.68      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.52      0.50      0.38      5526
# weighted avg       0.52      0.53      0.40      5526
#
#
#  DESWLltd__DESPLd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__LogisticRegression : 52.9 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.01      0.02      2613
#         Real       0.53      0.99      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.57      0.50      0.36      5526
# weighted avg       0.57      0.53      0.37      5526
#
#
#  DESWLltd__DESPLd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__RandomForestClassifier : 46.89 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.24      0.06      0.09      2613
#         Real       0.50      0.84      0.62      2913
#
#     accuracy                           0.47      5526
#    macro avg       0.37      0.45      0.36      5526
# weighted avg       0.38      0.47      0.37      5526
#
#
#  DESWLltd__DESPLd__SVC
#
#
# OVERALL ACCURACY DESWLltd__DESPLd__SVC : 52.61 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.35      0.00      0.01      2613
#         Real       0.53      1.00      0.69      2913
#
#     accuracy                           0.53      5526
#    macro avg       0.44      0.50      0.35      5526
# weighted avg       0.44      0.53      0.37      5526
#
#
#  DESWLltd__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__KNeighborsClassifier : 43.36 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.46      0.83      0.59      3159
#         Real       0.20      0.04      0.07      3171
#
#     accuracy                           0.43      6330
#    macro avg       0.33      0.43      0.33      6330
# weighted avg       0.33      0.43      0.33      6330
#
#
#  DESWLltd__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__LogisticRegression : 99.12 %
#
#               precision    recall  f1-score   support
#
#         Fake       1.00      0.99      0.99      3159
#         Real       0.99      1.00      0.99      3171
#
#     accuracy                           0.99      6330
#    macro avg       0.99      0.99      0.99      6330
# weighted avg       0.99      0.99      0.99      6330
#
#
#  DESWLltd__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__RandomForestClassifier : 83.97 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.93      0.74      0.82      3159
#         Real       0.78      0.94      0.85      3171
#
#     accuracy                           0.84      6330
#    macro avg       0.85      0.84      0.84      6330
# weighted avg       0.85      0.84      0.84      6330
#
#
#  DESWLltd__SVC
#
#
# OVERALL ACCURACY DESWLltd__SVC : 58.75 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.55      1.00      0.71      3159
#         Real       0.98      0.18      0.30      3171
#
#     accuracy                           0.59      6330
#    macro avg       0.76      0.59      0.51      6330
# weighted avg       0.76      0.59      0.51      6330
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier : 71.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.64      0.96      0.77      3134
#         Real       0.92      0.46      0.62      3170
#
#     accuracy                           0.71      6304
#    macro avg       0.78      0.71      0.69      6304
# weighted avg       0.78      0.71      0.69      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression : 96.57 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.94      0.99      0.97      3134
#         Real       0.99      0.94      0.96      3170
#
#     accuracy                           0.97      6304
#    macro avg       0.97      0.97      0.97      6304
# weighted avg       0.97      0.97      0.97      6304
#
#
#  DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier : 60.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.56      0.97      0.71      3134
#         Real       0.90      0.24      0.37      3170
#
#     accuracy                           0.60      6304
#    macro avg       0.73      0.61      0.54      6304
# weighted avg       0.73      0.60      0.54      6304
# C:\Users\alber\AppData\Local\Temp\ipykernel_7784\3721647332.py:97: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
#  DESWLltd__WORD_PROPERTY_WRDHYPn__SVC
#
#
# OVERALL ACCURACY DESWLltd__WORD_PROPERTY_WRDHYPn__SVC : 70.62 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.99      0.77      3134
#         Real       0.99      0.42      0.59      3170
#
#     accuracy                           0.71      6304
#    macro avg       0.81      0.71      0.68      6304
# weighted avg       0.81      0.71      0.68      6304

# %%
print(len(list_dicts_performance))
print(list_dicts_performance)
# Out:
# 24
# [{'name': 'All_features__KNeighborsClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5291880271208864, 'precision_true': array([0.51252329]), 'recall_true': array([0.83423181]), 'f1_score_true': array([0.6349532]), 'precision_false': array([0.59539474]), 'recall_false': array([0.23514128]), 'f1_score_false': array([0.3371362]), 'confussion_matrix': array([[ 724,  492],
#        [2355, 2476]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'All_features__LogisticRegression', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'LogisticRegression', 'accuracy': 0.5642467339176451, 'precision_true': array([0.68479467]), 'recall_true': array([0.2078841]), 'f1_score_true': array([0.31894546]), 'precision_false': array([0.5431403]), 'recall_false': array([0.90776226]), 'f1_score_false': array([0.67963526]), 'confussion_matrix': array([[2795, 2351],
#        [ 284,  617]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'All_features__RandomForestClassifier', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'RandomForestClassifier', 'accuracy': 0.4772614519596494, 'precision_true': array([0.4820865]), 'recall_true': array([0.875]), 'f1_score_true': array([0.62166367]), 'precision_false': array([0.43787879]), 'recall_false': array([0.09386164]), 'f1_score_false': array([0.15458679]), 'confussion_matrix': array([[ 289,  371],
#        [2790, 2597]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'All_features__SVC', 'features': ['DESPC', 'DESSC', 'DESWC', 'DESPL', 'DESPLw', 'DESSL', 'DESSLd', 'DESWLsy', 'DESWLsyd', 'DESWLlt', 'DESWLltd', 'LDTTRc', 'LDTTRa', 'LDMTLD', 'LDHDD', 'SYNLE', 'SYNNP', 'SYNMEDpos', 'SYNMEDwrd', 'SYNMEDlem', 'SYNSTRUTa', 'RDFRE', 'READFKGL', 'TOKEN_ATTRIBUTE_RATIO_ALHPA', 'TOKEN_ATTRIBUTE_RATIO_DIGIT', 'TOKEN_ATTRIBUTE_RATIO_PUNCT', 'TOKEN_ATTRIBUTE_RATIO_URL', 'WORD_SET_INCIDENCE_WRDPRP1s', 'WORD_SET_INCIDENCE_WRDPRP1p', 'WORD_SET_INCIDENCE_WRDPRP2', 'WORD_SET_INCIDENCE_WRDPRP3s', 'WORD_SET_INCIDENCE_WRDPRP3p', 'WORD_SET_INCIDENCE_CNCCaus', 'WORD_SET_INCIDENCE_CNCLogic', 'WORD_SET_INCIDENCE_CNCTemp', 'WORD_SET_INCIDENCE_CNCAdd', 'WORD_SET_INCIDENCE_CNCPos', 'WORD_SET_INCIDENCE_CNCNeg', 'WORD_PROPERTY_WRDNOUN', 'WORD_PROPERTY_WRDVERB', 'WORD_PROPERTY_WRDADJ', 'WORD_PROPERTY_WRDADV', 'WORD_PROPERTY_WRDFRQc', 'WORD_PROPERTY_WRDFRQa', 'WORD_PROPERTY_WRDFRQmc', 'WORD_PROPERTY_WRDFAMc', 'WORD_PROPERTY_WRDCNCc', 'WORD_PROPERTY_WRDIMGc', 'WORD_PROPERTY_WRDMEAc', 'WORD_PROPERTY_WRDPOLc', 'WORD_PROPERTY_WRDHYPn', 'WORD_PROPERTY_WRDHYPv', 'WORD_PROPERTY_WRDHYPnv', 'WORD_PROPERTY_AOA', 'WORD_PROPERTY_AOA_MAX', 'WORD_PROPERTY_CONCRETENESS', 'WORD_PROPERTY_PREVALENCE', 'WORD_PROPERTY_PREVALENCE_MIN', 'WORD_SET_INCIDENCE_C4_COMMON_WORDS'], 'model': 'SVC', 'accuracy': 0.4947908053580288, 'precision_true': array([0.45945946]), 'recall_true': array([0.16610512]), 'f1_score_true': array([0.24399901]), 'precision_false': array([0.50241255]), 'recall_false': array([0.81162715]), 'f1_score_false': array([0.62063827]), 'confussion_matrix': array([[2499, 2475],
#        [ 580,  493]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.8577633007600435, 'precision_true': array([0.81270215]), 'recall_true': array([0.94884998]), 'f1_score_true': array([0.87551473]), 'precision_false': array([0.92988235]), 'recall_false': array([0.75621891]), 'f1_score_false': array([0.83410722]), 'confussion_matrix': array([[1976,  149],
#        [ 637, 2764]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5334781035106768, 'precision_true': array([0.5307961]), 'recall_true': array([0.99107449]), 'f1_score_true': array([0.69133142]), 'precision_false': array([0.70114943]), 'recall_false': array([0.02334481]), 'f1_score_false': array([0.04518519]), 'confussion_matrix': array([[  61,   26],
#        [2552, 2887]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.50542888165038, 'precision_true': array([0.51893939]), 'recall_true': array([0.84654995]), 'f1_score_true': array([0.64344423]), 'precision_false': array([0.42248062]), 'recall_false': array([0.12514351]), 'f1_score_false': array([0.19309123]), 'confussion_matrix': array([[ 327,  447],
#        [2286, 2466]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5253347810351068, 'precision_true': array([0.52638282]), 'recall_true': array([0.99313423]), 'f1_score_true': array([0.6880723]), 'precision_false': array([0.33333333]), 'recall_false': array([0.00382702]), 'f1_score_false': array([0.00756716]), 'confussion_matrix': array([[  10,   20],
#        [2603, 2893]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.49022801302931596, 'precision_true': array([0.50953895]), 'recall_true': array([0.88019224]), 'f1_score_true': array([0.64543738]), 'precision_false': array([0.29352227]), 'recall_false': array([0.05549177]), 'f1_score_false': array([0.09333762]), 'confussion_matrix': array([[ 145,  349],
#        [2468, 2564]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.5139341295693087, 'precision_true': array([0.52099907]), 'recall_true': array([0.966701]), 'f1_score_true': array([0.67708584]), 'precision_false': array([0.19834711]), 'recall_false': array([0.00918485]), 'f1_score_false': array([0.01755669]), 'confussion_matrix': array([[  24,   97],
#        [2589, 2816]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.8859934853420195, 'precision_true': array([0.89321392]), 'recall_true': array([0.89014761]), 'f1_score_true': array([0.89167813]), 'precision_false': array([0.87800229]), 'recall_false': array([0.88136242]), 'f1_score_false': array([0.87967914]), 'confussion_matrix': array([[2303,  320],
#        [ 310, 2593]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.5246109301483894, 'precision_true': array([0.52599055]), 'recall_true': array([0.99347751]), 'f1_score_true': array([0.68781937]), 'precision_false': array([0.20833333]), 'recall_false': array([0.00191351]), 'f1_score_false': array([0.00379219]), 'confussion_matrix': array([[   5,   19],
#        [2608, 2894]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__DESPLd__KNeighborsClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.5273253709735795, 'precision_true': array([0.5284876]), 'recall_true': array([0.95846207]), 'f1_score_true': array([0.68130796]), 'precision_false': array([0.50205761]), 'recall_false': array([0.04668963]), 'f1_score_false': array([0.08543417]), 'confussion_matrix': array([[ 122,  121],
#        [2491, 2792]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__DESPLd__LogisticRegression', 'features': ['DESWLltd', 'DESPLd'], 'model': 'LogisticRegression', 'accuracy': 0.5289540354686935, 'precision_true': array([0.52827435]), 'recall_true': array([0.99416409]), 'f1_score_true': array([0.68993448]), 'precision_false': array([0.61363636]), 'recall_false': array([0.01033295]), 'f1_score_false': array([0.02032367]), 'confussion_matrix': array([[  27,   17],
#        [2586, 2896]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__DESPLd__RandomForestClassifier', 'features': ['DESWLltd', 'DESPLd'], 'model': 'RandomForestClassifier', 'accuracy': 0.46887441187115453, 'precision_true': array([0.49775693]), 'recall_true': array([0.83796773]), 'f1_score_true': array([0.62453627]), 'precision_false': array([0.24115756]), 'recall_false': array([0.05740528]), 'f1_score_false': array([0.0927357]), 'confussion_matrix': array([[ 150,  472],
#        [2463, 2441]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__DESPLd__SVC', 'features': ['DESWLltd', 'DESPLd'], 'model': 'SVC', 'accuracy': 0.5260586319218241, 'precision_true': array([0.52669815]), 'recall_true': array([0.99553725]), 'f1_score_true': array([0.68891792]), 'precision_false': array([0.35]), 'recall_false': array([0.00267891]), 'f1_score_false': array([0.00531713]), 'confussion_matrix': array([[   7,   13],
#        [2606, 2900]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__KNeighborsClassifier', 'features': ['DESWLltd'], 'model': 'KNeighborsClassifier', 'accuracy': 0.43364928909952605, 'precision_true': array([0.19912791]), 'recall_true': array([0.04320404]), 'f1_score_true': array([0.07100285]), 'precision_false': array([0.46224743]), 'recall_false': array([0.82557771]), 'f1_score_false': array([0.59265993]), 'confussion_matrix': array([[2608, 3034],
#        [ 551,  137]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__LogisticRegression', 'features': ['DESWLltd'], 'model': 'LogisticRegression', 'accuracy': 0.9911532385466034, 'precision_true': array([0.98565638]), 'recall_true': array([0.99684642]), 'f1_score_true': array([0.99121982]), 'precision_false': array([0.99679795]), 'recall_false': array([0.98543843]), 'f1_score_false': array([0.99108564]), 'confussion_matrix': array([[3113,   10],
#        [  46, 3161]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__RandomForestClassifier', 'features': ['DESWLltd'], 'model': 'RandomForestClassifier', 'accuracy': 0.839652448657188, 'precision_true': array([0.78249476]), 'recall_true': array([0.94165878]), 'f1_score_true': array([0.85473021]), 'precision_false': array([0.92641209]), 'recall_false': array([0.73725863]), 'f1_score_false': array([0.82108232]), 'confussion_matrix': array([[2329,  185],
#        [ 830, 2986]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__SVC', 'features': ['DESWLltd'], 'model': 'SVC', 'accuracy': 0.587519747235387, 'precision_true': array([0.98109966]), 'recall_true': array([0.18006938]), 'f1_score_true': array([0.3042899]), 'precision_false': array([0.54766875]), 'recall_false': array([0.99651789]), 'f1_score_false': array([0.70685977]), 'confussion_matrix': array([[3148, 2600],
#        [  11,  571]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'KNeighborsClassifier', 'accuracy': 0.7100253807106599, 'precision_true': array([0.92468354]), 'recall_true': array([0.46088328]), 'f1_score_true': array([0.61515789]), 'precision_false': array([0.63823031]), 'recall_false': array([0.96202936]), 'f1_score_false': array([0.76737083]), 'confussion_matrix': array([[3015, 1709],
#        [ 119, 1461]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'LogisticRegression', 'accuracy': 0.9657360406091371, 'precision_true': array([0.99266177]), 'recall_true': array([0.93880126]), 'f1_score_true': array([0.96498054]), 'precision_false': array([0.94131881]), 'recall_false': array([0.99298022]), 'f1_score_false': array([0.96645963]), 'confussion_matrix': array([[3112,  194],
#        [  22, 2976]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'RandomForestClassifier', 'accuracy': 0.6032677664974619, 'precision_true': array([0.90349819]), 'recall_true': array([0.2362776]), 'f1_score_true': array([0.37459365]), 'precision_false': array([0.55780822]), 'recall_false': array([0.97447352]), 'f1_score_false': array([0.70949007]), 'confussion_matrix': array([[3054, 2421],
#        [  80,  749]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}, {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC', 'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'], 'model': 'SVC', 'accuracy': 0.7062182741116751, 'precision_true': array([0.98814815]), 'recall_true': array([0.42082019]), 'f1_score_true': array([0.59026549]), 'precision_false': array([0.62939039]), 'recall_false': array([0.9948947]), 'f1_score_false': array([0.77101879]), 'confussion_matrix': array([[3118, 1836],
#        [  16, 1334]], dtype=int64), 'data_test_source': 'second dataset', 'training_normalized_together': 'yes', 'testing_normalized_together': 'no'}]

# %% [markdown]
# do a mirror pair of models trained with this data and tested in the second dataset/fine tune

# %% [markdown]
# '''
#
# small crossvalidation to make sure model is stableand std bt the scores , lucky distr.
#
# data augmentation - + at the end with the generation model, feed the model with new elements
#
# method to input some text and see the prediction irt,
# automatically add fake news text to the data
#
#
# this is quant but we need qualitative
#
# SMOTE libary for DAug
#
# name of the file and template of the acl file - subsections things
#
# qualitative vs quantitative studies
#
# '''

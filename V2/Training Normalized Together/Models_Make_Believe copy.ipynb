# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score

from sklearn.metrics import precision_recall_fscore_support


import pickle

import json

# %%
from json import JSONEncoder
import json
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %% [markdown]
# # Model functions

# %%
def data_preprocess(data):
  '''We input the data with the linguistic features
  And it returns the data with the polarity columns in 0 for fake and 1 for true
  as well as the outcomes
  '''

  if data["Polarity"][0] != 0 or 1:
    data["Polarity"] = data["Polarity"].replace("Fake", 0)
    data["Polarity"] = data["Polarity"].replace("TRUE", 1)

  outcomes = ["Fake","Real"]
  
  return data, outcomes

def test_train(data, features):

  '''We input the data with the features and a list of the features we want to pass to the models.
  it returns the data split in test/train
  '''

  feature_cols = features
  data = data[feature_cols + ["Polarity"]].dropna()

  X = data[feature_cols]
  y = data["Polarity"] #outcomes 0 or 1


  print("Info: {} features were passed at the fit step\n:".format(X.shape[1]))
  for feature in feature_cols:
    print(feature)

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=16) #stratify so that the proportion of the train data is the same for fake and true

  return X, y, X_train, X_test, y_train, y_test, features

def class_report(y_test, y_pred):

  outcomes = ["Fake","Real"]

  scores = classification_report(y_test, y_pred, target_names=outcomes)

  print(scores)

  return scores

def compare_models_cross_val(model, X, y):
  
  '''for each model, it calculates the cross validation accuracy for each iteration
  as well as the mean cross validation score on the given data

  '''

  print("CROSS VALIDATION\n")

  model_name = str(model)[:-2]

  if model_name == "SVC(kernel=\'linear":

    model_name = "SVC"


  # for model in models:
  cv_score = cross_val_score(model, X, y, cv = 5)
  print("Cross validation accuracy {} for each of the 5 iterations:".format(model_name))
  for score in cv_score:
    print(round(score*100, 2), "%")

  mean_accuracy = sum(cv_score)/len(cv_score)

  print("\nCross validation mean accuracy for {}:".format(model_name), round(mean_accuracy*100, 2),"%")
  print("\n-------------------------------------------------------------------------\n")

  return cv_score, mean_accuracy

def conf_matrix(model_name, features, y_pred, y_test, cmap="magma"):

  '''This function takes the predicted and test labels, generates the confusion matrix
  and displays it
  '''

  n_features = len(features)

  confussion_matrix = confusion_matrix(y_pred, y_test)

  outcomes = ["Fake","Real"]
  ticks = np.arange(len(outcomes))

  fig, ax = plt.subplots()
  plt.xticks(ticks, outcomes)
  plt.yticks(ticks, outcomes)
  sns.heatmap(pd.DataFrame(confussion_matrix), annot=True, cmap=cmap, fmt="g", xticklabels=outcomes, yticklabels=outcomes)
  ax.xaxis.set_label_position("top")
  plt.tight_layout()
  if n_features == 1:

    plt.title("{} Confusion Matrix: {}".format(model_name, features[0]), y = 1.1)

  elif n_features == 2:

    plt.title("{} Confusion Matrix: {} and {}".format(model_name, features[0],features[1]), y = 1.1)

  elif n_features == 3:

    plt.title("{} Confusion Matrix: {}, {} and {}".format(model_name, features[0],features[1], features[2]), y = 1.1)

  plt.ylabel("Actual label")
  plt.xlabel("Predicted label")

  return confussion_matrix

def compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features):

  '''this fx trains the data on the four types of models,
  generates a report with the overall accuracy of the model, the cross validation evaluation
  and prints the confussion matrix of each model on the particular test_train split.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the cross-validation evaluation and the confusion matrix
  '''

  model_list_dicts =[]

  for model in models:
    
    model_name = str(model)[:-2]

    if model_name == "SVC(kernel=\'linear":

      model_name = "SVC"
    
    model_dict = {}
    
    ft_str = str(features)[2:-2].replace("'","_").replace(",", "_").replace(" ", "_").replace("___", "_")
    
    model_dict["name"] = ft_str + "__" + model_name
    
    model_dict["features"] = features

    model_dict["model"] = model_name
    
    print("\n",model_name, "\n", "\n")
    
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    
    model_dict["accuracy"] = accuracy
    
    print("OVERALL ACCURACY", model_name, ":", round(accuracy*100, 2),"%""\n")
    
    scores = class_report(y_test, y_pred)
    
    P_R_F1_true = precision_recall_fscore_support(y_test, y_pred, labels=[1])
    precision_true, recall_true , f1_score_true  = P_R_F1_true[0], P_R_F1_true[1] ,  P_R_F1_true[2]
    
    P_R_F1_false = precision_recall_fscore_support(y_test, y_pred, labels=[0])
    precision_false, recall_false, f1_score_false = P_R_F1_false[0], P_R_F1_false[1], P_R_F1_false[2]
    
    model_dict["precision_true"], model_dict["recall_true"], model_dict["f1_score_true"] = precision_true, recall_true, f1_score_true
    model_dict["precision_false"], model_dict["recall_false"], model_dict["f1_score_false"] = precision_false, recall_false, f1_score_false

    cv_score, mean_accuracy = compare_models_cross_val(model, X, y)
    
    model_dict["cv_scores"] = cv_score

    model_dict["mean_cv_accuracy"] = mean_accuracy
    
    confussion_matrix = conf_matrix(model_name, features, y_pred, y_test, cmap="magma")
    
    model_dict["confussion_matrix"] = confussion_matrix
    
    model_dict["data_test_source"] = "training dataset"
    
    model_dict["training_normalized_together"] = "yes"

    model_dict["testing_normalized_together"] = "yes, subset of training"

    model_list_dicts.append(model_dict)
    
    pickle.dump(model, open(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\MODELS\{}.sav".format(ft_str + "__" + model_name), 'wb'))
    
      
    with open(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\Training Normalized Together\DICTS\{}.json".format(model_dict["name"]), "w") as f:
      json.dump(model_dict, f, cls=NumpyArrayEncoder)
  
  
  return model_list_dicts

def magic(data, features):

  '''this function takes all the previous functions and integrates them into a single function to run the data processing, training and testing in all the models.

  It returns a dictionary with the name of the model, the features that were passed during the fit,
  the model used, the accuracy score, the classification report, the crossvalidation evaluation and the confusion matrix

  '''

  data, outcomes = data_preprocess(data) # data in the correct format for the y outcomes

  X, y, X_train, X_test, y_train, y_test, features = test_train(data, features) # data split for all the models with the desired features

  model_list_dicts = compare_models_train_test_split(models, X, y, X_train, y_train, X_test, y_test, features) # for each model it will compute

  return model_list_dicts

# %%
models = [LogisticRegression(), SVC(kernel ="linear"), KNeighborsClassifier(), RandomForestClassifier()]

# %% [markdown]
# # Loading our data

# %%
final_fts = pd.read_csv(r"C:\Users\alber\Desktop\Make Believe Diciembre\V2\three_final_features_normalized_together.csv")
print(final_fts.shape)
final_fts
# Out:
# (480, 4)
#        DESPLd  DESWLltd  WORD_PROPERTY_WRDHYPn  Polarity
# 0    0.000000  0.245928               0.404405         0
# 1    0.176471  0.054558               0.420646         0
# 2    0.235294  0.048796               0.561619         0
# 3    0.176471  0.052436               0.558820         0
# 4    0.294118  0.055620               0.666625         0
# ..        ...       ...                    ...       ...
# 475  0.176471  0.080692               0.506349         1
# 476  0.037203  0.019553               0.455246         1
# 477  0.048029  0.113189               0.592211         1
# 478  0.352941  0.084673               0.492107         1
# 479  0.058824  0.138384               0.633193         1
#
# [480 rows x 4 columns]

# %% [markdown]
# # Models using all the 3 features
#
# ---

# %%
features = ['DESPLd',	'DESWLltd',	'WORD_PROPERTY_WRDHYPn']

models_all_features = magic(final_fts, features)
# Out:
# Info: 3 features were passed at the fit step
# :
# DESPLd
# DESWLltd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.52 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.60      0.28      0.38        53
#         Real       0.57      0.83      0.68        60
#
#     accuracy                           0.58       113
#    macro avg       0.58      0.56      0.53       113
# weighted avg       0.58      0.58      0.54       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 56.67 %
# 54.44 %
# 55.56 %
# 58.89 %
# 54.44 %
#
# Cross validation mean accuracy for LogisticRegression: 56.0 %
#
# -------------------------------------------------------------------------
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.1 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.08      0.13        53
#         Real       0.53      0.93      0.68        60
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.50      0.40       113
# weighted avg       0.52      0.53      0.42       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 57.78 %
# 54.44 %
# 53.33 %
# 57.78 %
# 52.22 %
#
# Cross validation mean accuracy for SVC: 55.11 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 59.29 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.49      0.53        53
#         Real       0.60      0.68      0.64        60
#
#     accuracy                           0.59       113
#    macro avg       0.59      0.59      0.59       113
# weighted avg       0.59      0.59      0.59       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 61.11 %
# 63.33 %
# 63.33 %
# 57.78 %
# 66.67 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 62.44 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 62.83 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.57      0.59        53
#         Real       0.64      0.68      0.66        60
#
#     accuracy                           0.63       113
#    macro avg       0.63      0.62      0.62       113
# weighted avg       0.63      0.63      0.63       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 61.11 %
# 55.56 %
# 62.22 %
# 66.67 %
# 65.56 %
#
# Cross validation mean accuracy for RandomForestClassifier: 62.22 %
#
# -------------------------------------------------------------------------

# %%
models_all_features
# Out:
# [{'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression',
#   'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'LogisticRegression',
#   'accuracy': 0.5752212389380531,
#   'precision_true': array([0.56818182]),
#   'recall_true': array([0.83333333]),
#   'f1_score_true': array([0.67567568]),
#   'precision_false': array([0.6]),
#   'recall_false': array([0.28301887]),
#   'f1_score_false': array([0.38461538]),
#   'cv_scores': array([0.56666667, 0.54444444, 0.55555556, 0.58888889, 0.54444444]),
#   'mean_cv_accuracy': 0.5599999999999999,
#   'confussion_matrix': array([[15, 10],
#          [38, 50]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__SVC',
#   'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'SVC',
#   'accuracy': 0.5309734513274337,
#   'precision_true': array([0.53333333]),
#   'recall_true': array([0.93333333]),
#   'f1_score_true': array([0.67878788]),
#   'precision_false': array([0.5]),
#   'recall_false': array([0.0754717]),
#   'f1_score_false': array([0.13114754]),
#   'cv_scores': array([0.57777778, 0.54444444, 0.53333333, 0.57777778, 0.52222222]),
#   'mean_cv_accuracy': 0.5511111111111111,
#   'confussion_matrix': array([[ 4,  4],
#          [49, 56]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier',
#   'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'KNeighborsClassifier',
#   'accuracy': 0.5929203539823009,
#   'precision_true': array([0.60294118]),
#   'recall_true': array([0.68333333]),
#   'f1_score_true': array([0.640625]),
#   'precision_false': array([0.57777778]),
#   'recall_false': array([0.49056604]),
#   'f1_score_false': array([0.53061224]),
#   'cv_scores': array([0.61111111, 0.63333333, 0.63333333, 0.57777778, 0.66666667]),
#   'mean_cv_accuracy': 0.6244444444444445,
#   'confussion_matrix': array([[26, 19],
#          [27, 41]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier',
#   'features': ['DESPLd', 'DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'RandomForestClassifier',
#   'accuracy': 0.6283185840707964,
#   'precision_true': array([0.640625]),
#   'recall_true': array([0.68333333]),
#   'f1_score_true': array([0.66129032]),
#   'precision_false': array([0.6122449]),
#   'recall_false': array([0.56603774]),
#   'f1_score_false': array([0.58823529]),
#   'cv_scores': array([0.61111111, 0.55555556, 0.62222222, 0.66666667, 0.65555556]),
#   'mean_cv_accuracy': 0.6222222222222222,
#   'confussion_matrix': array([[30, 19],
#          [23, 41]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'}]

# %% [markdown]
# # Models excluding different features each time

# %% [markdown]
# DESWLltd and WORD_PROPERTY_WRDHYPn

# %%
features = ['DESWLltd',	'WORD_PROPERTY_WRDHYPn']
models_DESWLltd_WORD_PROPERTY_WRDHYPn = magic(final_fts, features)
# Out:
# Info: 2 features were passed at the fit step
# :
# DESWLltd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.58      0.55      0.56        60
#         Real       0.57      0.60      0.59        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 58.33 %
# 60.42 %
# 59.38 %
# 46.88 %
# 63.54 %
#
# Cross validation mean accuracy for LogisticRegression: 57.71 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 50.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.65      0.57        60
#         Real       0.50      0.35      0.41        60
#
#     accuracy                           0.50       120
#    macro avg       0.50      0.50      0.49       120
# weighted avg       0.50      0.50      0.49       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 56.25 %
# 63.54 %
# 58.33 %
# 44.79 %
# 50.0 %
#
# Cross validation mean accuracy for SVC: 54.58 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 51.67 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.52      0.47      0.49        60
#         Real       0.52      0.57      0.54        60
#
#     accuracy                           0.52       120
#    macro avg       0.52      0.52      0.52       120
# weighted avg       0.52      0.52      0.52       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 52.08 %
# 55.21 %
# 46.88 %
# 50.0 %
# 53.12 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 51.46 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 48.33 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.48      0.45      0.47        60
#         Real       0.48      0.52      0.50        60
#
#     accuracy                           0.48       120
#    macro avg       0.48      0.48      0.48       120
# weighted avg       0.48      0.48      0.48       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 52.08 %
# 54.17 %
# 45.83 %
# 52.08 %
# 56.25 %
#
# Cross validation mean accuracy for RandomForestClassifier: 52.08 %
#
# -------------------------------------------------------------------------

# %%
models_DESWLltd_WORD_PROPERTY_WRDHYPn
# Out:
# [{'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__LogisticRegression',
#   'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'LogisticRegression',
#   'accuracy': 0.575,
#   'precision_true': array([0.57142857]),
#   'recall_true': array([0.6]),
#   'f1_score_true': array([0.58536585]),
#   'precision_false': array([0.57894737]),
#   'recall_false': array([0.55]),
#   'f1_score_false': array([0.56410256]),
#   'cv_scores': array([0.58333333, 0.60416667, 0.59375   , 0.46875   , 0.63541667]),
#   'mean_cv_accuracy': 0.5770833333333333,
#   'confussion_matrix': array([[33, 24],
#          [27, 36]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__SVC',
#   'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'SVC',
#   'accuracy': 0.5,
#   'precision_true': array([0.5]),
#   'recall_true': array([0.35]),
#   'f1_score_true': array([0.41176471]),
#   'precision_false': array([0.5]),
#   'recall_false': array([0.65]),
#   'f1_score_false': array([0.56521739]),
#   'cv_scores': array([0.5625    , 0.63541667, 0.58333333, 0.44791667, 0.5       ]),
#   'mean_cv_accuracy': 0.5458333333333333,
#   'confussion_matrix': array([[39, 39],
#          [21, 21]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier',
#   'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'KNeighborsClassifier',
#   'accuracy': 0.5166666666666667,
#   'precision_true': array([0.51515152]),
#   'recall_true': array([0.56666667]),
#   'f1_score_true': array([0.53968254]),
#   'precision_false': array([0.51851852]),
#   'recall_false': array([0.46666667]),
#   'f1_score_false': array([0.49122807]),
#   'cv_scores': array([0.52083333, 0.55208333, 0.46875   , 0.5       , 0.53125   ]),
#   'mean_cv_accuracy': 0.5145833333333334,
#   'confussion_matrix': array([[28, 26],
#          [32, 34]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier',
#   'features': ['DESWLltd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'RandomForestClassifier',
#   'accuracy': 0.48333333333333334,
#   'precision_true': array([0.484375]),
#   'recall_true': array([0.51666667]),
#   'f1_score_true': array([0.5]),
#   'precision_false': array([0.48214286]),
#   'recall_false': array([0.45]),
#   'f1_score_false': array([0.46551724]),
#   'cv_scores': array([0.52083333, 0.54166667, 0.45833333, 0.52083333, 0.5625    ]),
#   'mean_cv_accuracy': 0.5208333333333333,
#   'confussion_matrix': array([[27, 29],
#          [33, 31]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'}]

# %% [markdown]
# DESPLd and	WORD_PROPERTY_WRDHYPn

# %%
features = ['DESPLd',	'WORD_PROPERTY_WRDHYPn']
models_DESPLd_WORD_PROPERTY_WRDHYPn = magic(final_fts, features)
# Out:
# Info: 2 features were passed at the fit step
# :
# DESPLd
# WORD_PROPERTY_WRDHYPn
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 59.29 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.63      0.32      0.42        53
#         Real       0.58      0.83      0.68        60
#
#     accuracy                           0.59       113
#    macro avg       0.61      0.58      0.55       113
# weighted avg       0.60      0.59      0.56       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 56.67 %
# 52.22 %
# 55.56 %
# 60.0 %
# 56.67 %
#
# Cross validation mean accuracy for LogisticRegression: 56.22 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.1 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.02      0.04        53
#         Real       0.53      0.98      0.69        60
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.50      0.36       113
# weighted avg       0.52      0.53      0.38       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 56.67 %
# 53.33 %
# 55.56 %
# 56.67 %
# 52.22 %
#
# Cross validation mean accuracy for SVC: 54.89 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 58.41 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.56      0.53      0.54        53
#         Real       0.60      0.63      0.62        60
#
#     accuracy                           0.58       113
#    macro avg       0.58      0.58      0.58       113
# weighted avg       0.58      0.58      0.58       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 66.67 %
# 65.56 %
# 62.22 %
# 56.67 %
# 60.0 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 62.22 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 69.03 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.69      0.62      0.65        53
#         Real       0.69      0.75      0.72        60
#
#     accuracy                           0.69       113
#    macro avg       0.69      0.69      0.69       113
# weighted avg       0.69      0.69      0.69       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 64.44 %
# 63.33 %
# 68.89 %
# 62.22 %
# 65.56 %
#
# Cross validation mean accuracy for RandomForestClassifier: 64.89 %
#
# -------------------------------------------------------------------------

# %%
models_DESPLd_WORD_PROPERTY_WRDHYPn
# Out:
# [{'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__LogisticRegression',
#   'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'LogisticRegression',
#   'accuracy': 0.5929203539823009,
#   'precision_true': array([0.58139535]),
#   'recall_true': array([0.83333333]),
#   'f1_score_true': array([0.68493151]),
#   'precision_false': array([0.62962963]),
#   'recall_false': array([0.32075472]),
#   'f1_score_false': array([0.425]),
#   'cv_scores': array([0.56666667, 0.52222222, 0.55555556, 0.6       , 0.56666667]),
#   'mean_cv_accuracy': 0.5622222222222222,
#   'confussion_matrix': array([[17, 10],
#          [36, 50]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__SVC',
#   'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'SVC',
#   'accuracy': 0.5309734513274337,
#   'precision_true': array([0.53153153]),
#   'recall_true': array([0.98333333]),
#   'f1_score_true': array([0.69005848]),
#   'precision_false': array([0.5]),
#   'recall_false': array([0.01886792]),
#   'f1_score_false': array([0.03636364]),
#   'cv_scores': array([0.56666667, 0.53333333, 0.55555556, 0.56666667, 0.52222222]),
#   'mean_cv_accuracy': 0.5488888888888889,
#   'confussion_matrix': array([[ 1,  1],
#          [52, 59]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__KNeighborsClassifier',
#   'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'KNeighborsClassifier',
#   'accuracy': 0.584070796460177,
#   'precision_true': array([0.6031746]),
#   'recall_true': array([0.63333333]),
#   'f1_score_true': array([0.61788618]),
#   'precision_false': array([0.56]),
#   'recall_false': array([0.52830189]),
#   'f1_score_false': array([0.54368932]),
#   'cv_scores': array([0.66666667, 0.65555556, 0.62222222, 0.56666667, 0.6       ]),
#   'mean_cv_accuracy': 0.6222222222222222,
#   'confussion_matrix': array([[28, 22],
#          [25, 38]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESPLd__WORD_PROPERTY_WRDHYPn__RandomForestClassifier',
#   'features': ['DESPLd', 'WORD_PROPERTY_WRDHYPn'],
#   'model': 'RandomForestClassifier',
#   'accuracy': 0.6902654867256637,
#   'precision_true': array([0.69230769]),
#   'recall_true': array([0.75]),
#   'f1_score_true': array([0.72]),
#   'precision_false': array([0.6875]),
#   'recall_false': array([0.62264151]),
#   'f1_score_false': array([0.65346535]),
#   'cv_scores': array([0.64444444, 0.63333333, 0.68888889, 0.62222222, 0.65555556]),
#   'mean_cv_accuracy': 0.6488888888888888,
#   'confussion_matrix': array([[33, 15],
#          [20, 45]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'}]

# %% [markdown]
# DESPLd and DESWLltd

# %%
features = ['DESWLltd',	'DESPLd']
models_DESWLltd_DESWLltd = magic(final_fts, features)
# Out:
# Info: 2 features were passed at the fit step
# :
# DESWLltd
# DESPLd
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 56.64 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.59      0.25      0.35        53
#         Real       0.56      0.85      0.68        60
#
#     accuracy                           0.57       113
#    macro avg       0.58      0.55      0.51       113
# weighted avg       0.57      0.57      0.52       113
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 57.78 %
# 54.44 %
# 55.56 %
# 58.89 %
# 54.44 %
#
# Cross validation mean accuracy for LogisticRegression: 56.22 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 53.1 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      0.08      0.13        53
#         Real       0.53      0.93      0.68        60
#
#     accuracy                           0.53       113
#    macro avg       0.52      0.50      0.40       113
# weighted avg       0.52      0.53      0.42       113
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 50.0 %
# 54.44 %
# 54.44 %
# 55.56 %
# 54.44 %
#
# Cross validation mean accuracy for SVC: 53.78 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 61.06 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.59      0.55      0.57        53
#         Real       0.62      0.67      0.65        60
#
#     accuracy                           0.61       113
#    macro avg       0.61      0.61      0.61       113
# weighted avg       0.61      0.61      0.61       113
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 55.56 %
# 55.56 %
# 64.44 %
# 58.89 %
# 60.0 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 58.89 %
#
# -------------------------------------------------------------------------
#
#
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 61.95 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.61      0.53      0.57        53
#         Real       0.63      0.70      0.66        60
#
#     accuracy                           0.62       113
#    macro avg       0.62      0.61      0.61       113
# weighted avg       0.62      0.62      0.62       113
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 57.78 %
# 56.67 %
# 62.22 %
# 68.89 %
# 60.0 %
#
# Cross validation mean accuracy for RandomForestClassifier: 61.11 %
#
# -------------------------------------------------------------------------

# %%
models_DESWLltd_DESWLltd
# Out:
# [{'name': 'DESWLltd__DESPLd__LogisticRegression',
#   'features': ['DESWLltd', 'DESPLd'],
#   'model': 'LogisticRegression',
#   'accuracy': 0.5663716814159292,
#   'precision_true': array([0.56043956]),
#   'recall_true': array([0.85]),
#   'f1_score_true': array([0.67549669]),
#   'precision_false': array([0.59090909]),
#   'recall_false': array([0.24528302]),
#   'f1_score_false': array([0.34666667]),
#   'cv_scores': array([0.57777778, 0.54444444, 0.55555556, 0.58888889, 0.54444444]),
#   'mean_cv_accuracy': 0.5622222222222222,
#   'confussion_matrix': array([[13,  9],
#          [40, 51]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__DESPLd__SVC',
#   'features': ['DESWLltd', 'DESPLd'],
#   'model': 'SVC',
#   'accuracy': 0.5309734513274337,
#   'precision_true': array([0.53333333]),
#   'recall_true': array([0.93333333]),
#   'f1_score_true': array([0.67878788]),
#   'precision_false': array([0.5]),
#   'recall_false': array([0.0754717]),
#   'f1_score_false': array([0.13114754]),
#   'cv_scores': array([0.5       , 0.54444444, 0.54444444, 0.55555556, 0.54444444]),
#   'mean_cv_accuracy': 0.5377777777777777,
#   'confussion_matrix': array([[ 4,  4],
#          [49, 56]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__DESPLd__KNeighborsClassifier',
#   'features': ['DESWLltd', 'DESPLd'],
#   'model': 'KNeighborsClassifier',
#   'accuracy': 0.6106194690265486,
#   'precision_true': array([0.625]),
#   'recall_true': array([0.66666667]),
#   'f1_score_true': array([0.64516129]),
#   'precision_false': array([0.59183673]),
#   'recall_false': array([0.54716981]),
#   'f1_score_false': array([0.56862745]),
#   'cv_scores': array([0.55555556, 0.55555556, 0.64444444, 0.58888889, 0.6       ]),
#   'mean_cv_accuracy': 0.5888888888888889,
#   'confussion_matrix': array([[29, 20],
#          [24, 40]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__DESPLd__RandomForestClassifier',
#   'features': ['DESWLltd', 'DESPLd'],
#   'model': 'RandomForestClassifier',
#   'accuracy': 0.6194690265486725,
#   'precision_true': array([0.62686567]),
#   'recall_true': array([0.7]),
#   'f1_score_true': array([0.66141732]),
#   'precision_false': array([0.60869565]),
#   'recall_false': array([0.52830189]),
#   'f1_score_false': array([0.56565657]),
#   'cv_scores': array([0.57777778, 0.56666667, 0.62222222, 0.68888889, 0.6       ]),
#   'mean_cv_accuracy': 0.6111111111111112,
#   'confussion_matrix': array([[28, 18],
#          [25, 42]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'}]

# %% [markdown]
# # Models using only DESWLltd, the unbalanced feature

# %% [markdown]
# DESWLltd
#
# ![OP feature probability distribution graphic.png](data:image/png;base64,...)

# %%
features = ['DESWLltd']
models_DESWLltd = magic(final_fts, features)
# Out:
# Info: 1 features were passed at the fit step
# :
# DESWLltd
#
#  LogisticRegression
#
#
# OVERALL ACCURACY LogisticRegression : 57.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.57      0.58      0.58        60
#         Real       0.58      0.57      0.57        60
#
#     accuracy                           0.57       120
#    macro avg       0.58      0.57      0.57       120
# weighted avg       0.58      0.57      0.57       120
#
# CROSS VALIDATION
#
# Cross validation accuracy LogisticRegression for each of the 5 iterations:
# 55.21 %
# 63.54 %
# 52.08 %
# 57.29 %
# 59.38 %
#
# Cross validation mean accuracy for LogisticRegression: 57.5 %
#
# -------------------------------------------------------------------------
#
#
#  SVC
#
#
# OVERALL ACCURACY SVC : 50.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.50      1.00      0.67        60
#         Real       0.00      0.00      0.00        60
#
#     accuracy                           0.50       120
#    macro avg       0.25      0.50      0.33       120
# weighted avg       0.25      0.50      0.33       120
#
# CROSS VALIDATION
#
# Cross validation accuracy SVC for each of the 5 iterations:
# 50.0 %
# 60.42 %
# 50.0 %
# 50.0 %
# 50.0 %
#
# Cross validation mean accuracy for SVC: 52.08 %
#
# -------------------------------------------------------------------------
#
#
#  KNeighborsClassifier
#
#
# OVERALL ACCURACY KNeighborsClassifier : 52.5 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.53      0.47      0.50        60
#         Real       0.52      0.58      0.55        60
#
#     accuracy                           0.53       120
#    macro avg       0.53      0.53      0.52       120
# weighted avg       0.53      0.53      0.52       120
#
# CROSS VALIDATION
#
# Cross validation accuracy KNeighborsClassifier for each of the 5 iterations:
# 47.92 %
# 47.92 %
# 44.79 %
# 54.17 %
# 57.29 %
#
# Cross validation mean accuracy for KNeighborsClassifier: 50.42 %
#
# -------------------------------------------------------------------------
# c:\Users\alber\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\alber\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\alber\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\alber\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  RandomForestClassifier
#
#
# OVERALL ACCURACY RandomForestClassifier : 55.0 %
#
#               precision    recall  f1-score   support
#
#         Fake       0.56      0.50      0.53        60
#         Real       0.55      0.60      0.57        60
#
#     accuracy                           0.55       120
#    macro avg       0.55      0.55      0.55       120
# weighted avg       0.55      0.55      0.55       120
#
# CROSS VALIDATION
#
# Cross validation accuracy RandomForestClassifier for each of the 5 iterations:
# 41.67 %
# 46.88 %
# 47.92 %
# 48.96 %
# 55.21 %
#
# Cross validation mean accuracy for RandomForestClassifier: 48.12 %
#
# -------------------------------------------------------------------------

# %%
models_DESWLltd
# Out:
# [{'name': 'DESWLltd__LogisticRegression',
#   'features': ['DESWLltd'],
#   'model': 'LogisticRegression',
#   'accuracy': 0.575,
#   'precision_true': array([0.57627119]),
#   'recall_true': array([0.56666667]),
#   'f1_score_true': array([0.57142857]),
#   'precision_false': array([0.57377049]),
#   'recall_false': array([0.58333333]),
#   'f1_score_false': array([0.5785124]),
#   'cv_scores': array([0.55208333, 0.63541667, 0.52083333, 0.57291667, 0.59375   ]),
#   'mean_cv_accuracy': 0.575,
#   'confussion_matrix': array([[35, 26],
#          [25, 34]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__SVC',
#   'features': ['DESWLltd'],
#   'model': 'SVC',
#   'accuracy': 0.5,
#   'precision_true': array([0.]),
#   'recall_true': array([0.]),
#   'f1_score_true': array([0.]),
#   'precision_false': array([0.5]),
#   'recall_false': array([1.]),
#   'f1_score_false': array([0.66666667]),
#   'cv_scores': array([0.5       , 0.60416667, 0.5       , 0.5       , 0.5       ]),
#   'mean_cv_accuracy': 0.5208333333333333,
#   'confussion_matrix': array([[60, 60],
#          [ 0,  0]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__KNeighborsClassifier',
#   'features': ['DESWLltd'],
#   'model': 'KNeighborsClassifier',
#   'accuracy': 0.525,
#   'precision_true': array([0.52238806]),
#   'recall_true': array([0.58333333]),
#   'f1_score_true': array([0.5511811]),
#   'precision_false': array([0.52830189]),
#   'recall_false': array([0.46666667]),
#   'f1_score_false': array([0.49557522]),
#   'cv_scores': array([0.47916667, 0.47916667, 0.44791667, 0.54166667, 0.57291667]),
#   'mean_cv_accuracy': 0.5041666666666667,
#   'confussion_matrix': array([[28, 25],
#          [32, 35]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'},
#  {'name': 'DESWLltd__RandomForestClassifier',
#   'features': ['DESWLltd'],
#   'model': 'RandomForestClassifier',
#   'accuracy': 0.55,
#   'precision_true': array([0.54545455]),
#   'recall_true': array([0.6]),
#   'f1_score_true': array([0.57142857]),
#   'precision_false': array([0.55555556]),
#   'recall_false': array([0.5]),
#   'f1_score_false': array([0.52631579]),
#   'cv_scores': array([0.41666667, 0.46875   , 0.47916667, 0.48958333, 0.55208333]),
#   'mean_cv_accuracy': 0.48125,
#   'confussion_matrix': array([[30, 24],
#          [30, 36]], dtype=int64),
#   'data_test_source': 'training dataset',
#   'training_normalized_together': 'yes',
#   'testing_normalized_together': 'yes, subset of training'}]
